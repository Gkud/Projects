# %%
import re
import dbus
import json
import spacy
import langid
import string
import spotipy
import requests
import flatdict
import itertools
import numpy as np
import pandas as pd
from time import time
import en_core_web_sm
from time import sleep
from random import randint
from fuzzywuzzy import fuzz
from bs4 import BeautifulSoup
from fuzzywuzzy import process
from collections import OrderedDict
from IPython.core.display import clear_output
from spotipy.oauth2 import SpotifyClientCredentials

# %%
def get_current_track_info():
    '''Connect with Spotify and fetch the currenlty playing track'''
    session_bus = dbus.SessionBus()
    try:
        spotify_bus = session_bus.get_object('org.mpris.MediaPlayer2.spotify', '/org/mpris/MediaPlayer2')
        spotify_properties = dbus.Interface(spotify_bus, 'org.freedesktop.DBus.Properties')
        metadata = spotify_properties.Get('org.mpris.MediaPlayer2.Player', 'Metadata')
        return {'artist': metadata['xesam:artist'][0], 'title': metadata['xesam:title'], 'trackId': metadata['mpris:trackid'], 'album': metadata['xesam:album']}
    except:
        print('Exception in Session Bus Interface')

class TrackInfo(object):
    '''A class containing methods to retrieve metada and lyrics of Spotify tracks'''
    
    def __init__(self, trackId):        
        ''' Instantiate spotify session
            Return: track object with its title, artist and album'''
        
        self.req = 0
        self.track_id = trackId
        self.trackDict = dict()

        # API tokens
        client_id = "314c62651741485eb3bdc9c07f8d5b73"
        client_secret = "e6d17930c5df497ba2fa1f1bfce6321b"
        redirect_url = "https://localhost:8888/callback"

        #Spotify api call
        try:
            client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
            self.sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
        except:
            print("Exception during Spotify session initialization")
        
        # Retrieve the track title, album name and artist names from spotify track metadata
        # If there are multiple artist append with '&'
        if self.sp:
            result = self.sp.track(self.track_id)
            self.req = self.req + 1
        if result:
            # Flatten the nested metadata dictionary. Nested keys are joined with '.' delimeter
            self.trackDict = flatdict.FlatDict(result, delimiter='.')
            self.title = self.trackDict['name']
            self.artist = ' & '.join([i['name'] for i in self.trackDict['artists']])
            self.album = self.trackDict['album.name']
            self.album_uri = self.trackDict['album.uri']
            self.artist_uri = [i['uri'] for i in self.trackDict['artists']]
    
    def processTrackName(self, title, album):
        '''Returns the processed name of the track by removing appended details like album
           This makes it possible to fetch the lyrics from Genius API by passing the track title
           as the API returns a null result if the track title is passed along with other appended details
        '''
        title = re.sub(r'[\(\[\{].*?[\)\]\}]', "", title)
        title = (title.split('-')[0]).strip()
        if album:
            ratio1 = fuzz.partial_ratio(album, title)
            ratio2 = fuzz.token_set_ratio(album, title)
            if ratio1 < 45 and ratio2 < 45:
                title = title.replace(album, '')
        return title.strip()
        
    def fetch_lyrics_page(self, song_title, artist_name):
        '''Make a request to Genius API to search and fetch the lyrics page of the track'''
        response = None
        base_url = 'https://api.genius.com'
        headers = {'Authorization': 'Bearer YkmxZvf4kNPOxSd3aTuuczGjWDZintTlgGLQYtjxAy4__gQbpl-EENB_LRb1Nwaz'}
        search_url = base_url + '/search'
        data = {'q': song_title + ' ' + artist_name}
        try:
            response = requests.get(search_url, data=data, headers=headers)
            self.req = self.req + 1
            geniusResponse = response.json()
            i = 0
            names = artist_name.split('&')
            while (not geniusResponse['response']['hits']) and (i < len(names)):   
                data = {'q': song_title + ' ' + names[i]}
                response = requests.get(search_url, data=data, headers=headers)
                self.req = self.req + 1
                geniusResponse = response.json()
                i = i + 1
                sleep(randint(2,4))
            return geniusResponse
        except:
            print("Exception during request call to Genius")
    
        
    def processStrings(self, strng):
        '''Returns a processed string after removing punctutaion and converting to lowercase'''
        strng = re.sub(r'[\W_]+', u'', strng, flags=re.UNICODE)
        return strng.lower()
    
    def findResponseMatch(self, geniusResponse, artist_names, trackTitle, albumName):
        '''Find a match of the song in Genius database to fetch the track lyrics
           Steps: 1) Find a match for the artist_name
                  2) If the artist_name matches, check if the track title matches
                  
            Algorithm to match Artist Name
            1) Search for a match with the exact name as present in music.artist column in dataset(inputString)
            2) If a match is not found,
               a) Remove punctutation from the name string along with whitespace
               b) Convert the string to lowercase
               c) Apply steps 'a' and 'b' to the string "match['result']['primary_artist']['name']" from response object (responseString)
               d) Apply approximate string matching (use fuzzywuzzy package)
            
            Algorithm to match Track Title
            1) Search for a match with the exact name as present in music.title column in dataset(inputTitle)
            2) 
            
            Returns: response object entry for which matches on the artist and track title names
        '''
        
        track_info = None
        bestMatch = None
        bestRatio = {'Ratio':0, 'Result': None}
        inputArtist = self.processStrings(artist_names)
        inputTitle = self.processStrings(trackTitle)
        
        #Iterate through the response object
        for match in geniusResponse['response']['hits']:
            result = None
            responseArtist = self.processStrings(match['result']['primary_artist']['name'])
            # Search a match with the exact name in music.artist dataset column
            if responseArtist:                
                if (responseArtist in inputArtist) or (inputArtist in responseArtist):
                    result = match['result']
                else:
                    ratio1 = fuzz.partial_ratio(inputArtist, responseArtist)
                    ratio2 = fuzz.token_set_ratio(inputArtist, responseArtist)
                    if ratio1 > 70 and ratio2 > 70:
                        result = match['result']
        
            # If a match for the artist_name is found, find a match for the title track
            if result:
                rtitle = self.processStrings(result['title'])
                titleFeat = self.processStrings(result['title_with_featured'])
                fullTitle = self.processStrings(result['full_title'])
                # Search a match with the exact name in music.title dataset column
                if (inputTitle == rtitle) or (inputTitle == titleFeat) or (inputTitle == fullTitle):
                    track_info = result
                    break
                # Remove punctuations and convert to lower case
                # Remove album name and artist names from the input string                
                else:
                    processedTitle = self.processStrings(trackTitle.split('-')[0])
                    if (processedTitle == rtitle) or (processedTitle == titleFeat) or (processedTitle == fullTitle):
                        bestMatch = result
                    else:
                        processedTitle = self.processTrackName(processedTitle, albumName)
                        if (processedTitle == rtitle) or (processedTitle == titleFeat) or (processedTitle == fullTitle):
                            bestMatch = result
                        else:
                            ratio1 = fuzz.partial_ratio(inputTitle, rtitle)
                            ratio2 = fuzz.token_set_ratio(inputTitle, rtitle)
                            if ratio1 > 70 and ratio2 > 70 and (ratio1+ratio2) > bestRatio['Ratio']:
                                bestRatio['Result'] = result                   
            else:
                continue
                
        if (not track_info) and (bestMatch):
            track_info = bestMatch
        elif bestRatio['Result']:
            track_info = bestRatio['Result'] 

        return track_info

    def scrape_lyrics_artist_title(self, genius_track_url):
        '''Get lyrics of the track
           Returns: song lyrics, track title (as found in Genius), artist name (as found in Genius)
        '''        
        lyrics = None
        foundArtistName = None
        foundTrackTitle = None    
        featuredArtistName = None
        producerName = None
        other_track_info = {}
        page = requests.get(genius_track_url)
        self.req = self.req + 1
        html = BeautifulSoup(page.text, 'html.parser')
        lyricsClass = html.find('div', class_='lyrics')
        if lyricsClass:
            lyrics = lyricsClass.get_text()
        if html.find('div', class_='header_with_cover_art-primary_info'):
            titleTag = html.find('h1', class_ = 'header_with_cover_art-primary_info-title')
            artistTag = html.find('a', class_ = 'header_with_cover_art-primary_info-primary_artist')
            otherTag = html.find_all('h3')
            for i in range(len(otherTag)):
                key = otherTag[i].find('span', {'class': 'metadata_unit-label'})
                value = otherTag[i].find('span', {'class': 'metadata_unit-info'})
                if key:
                    other_track_info[key.get_text()] = value.get_text()

            if titleTag:
                foundTrackTitle = titleTag.get_text()
            if artistTag:
                foundArtistName = artistTag.get_text()

        return (lyrics, foundTrackTitle, foundArtistName, other_track_info)

    def scrape_artist_bio(self, genius_artist_url):
        '''Get artist description through Genius API'''
        artist_bio = None
        page = requests.get(genius_artist_url)
        self.req = self.req + 1
        html = BeautifulSoup(page.text, 'html.parser')
        infoTag = html.find('div', class_='rich_text_formatting')
        if infoTag:
            artist_bio = infoTag.get_text()
        return artist_bio
    
    def getTrackLanguage(self, lyrics):
        '''Returns the language of the track'''
        
        #Dictionary with ISO-language codes mapped to languages
        codes = {"af":"Afrikaans", "am":"Amharic", "an":"Aragonese", "ar":"Arabic", "as":"Assamese", "az":"Azerbaijani",\
                "be":"Belarusian", "bg":"Bulgarian", "bn":"Bengali", "br":"Breton", "bs":"Bosnian",\
                "ca":"Catalan", "cs":"Czech", "cy":"Welsh", "da":"Danish", "de":"German", "dz":"Dzongkha",\
                "el":"Greek", "en":"English", "eo":"Esperanto", "es":"Spanish", "et":"Estonian", "eu":"Basque",\
                "fa":"Persian", "fi":"Finnish", "fo":"Faroese", "fr":"French", "ga":"Irish", "gl":"Galician", "gu":"Gujarati", \
                "he":"Hebrew", "hi":"Hindi", "hr":"Croatian", "ht":"Haitian", "hu":"Hungarian", "hy":"Armenian",\
                "id":"Indonesian", "is":"Icelandic", "it":"Italian", "ja":"Japanese", "jv":"Javanese", \
                "ka":"Georgian", "kk":"Kazakh", "km":"Central Khmer", "kn":"Kannada", "ko":"Korean", "ku":"Kurdish", "ky":"Kirghiz",\
                "la":"Latin", "lb":"Luxembourgish", "lo":"Lao", "lt":"Lithuanian", "lv":"Latvian", "mg":"Malagasy", "mk":"Macedonian", \
                "ml":"Malayalam", "mn":"Mongolian", "mr":"Marathi", "ms":"Malay", "mt":"Maltese", "nb":"Norwegian Bokmål", "ne":"Nepali",\
                "nl":"", "nn":"Norwegian Nynorsk", "no":"Norwegian", "oc":"Occitan", "or":"Oriya", "pa":"Punjabi", "pl":"Polish",\
                "ps":"Pashto", "pt":"Portuguese", "qu":"Quechua", "ro":"Romanian", "ru":"Russian", "rw":"Kinyarwanda",\
                "se":"Northern Sami", "si":"Sinhala", "sk":"Slovak", "sl":"Slovenian", "sq":"Albanian", "sr":"Serbian", \
                "sv":"Swedish", "sw":"Swahili", "ta":"Tamil", "te":"Telugu", "th":"Thai", "tl":"Tagalog", "tr":"Turkish",\
                "ug":"Uighur", "uk":"Ukrainian", "ur":"Urdu", "vi":"Vietnamese", "vo":"Volapük", \
                "wa":"Walloon", "xh":"Xhosa", "zh":"Chinese", "zu":"Zulu"}

        language = langid.classify(lyrics[0])
        return codes[language[0]]

    def getAudioFeatures(self):
        '''Returns Audio Features for a track'''
        self.req = self.req + 1
        return self.sp.audio_features(self.track_id)
    
    def getArtistGenre(self):
        '''Returns the Genre of the Artist'''
        genres = [(self.sp.artist(uri))['genres'] for uri in self.artist_uri]
        self.req = self.req + 1
        return list(itertools.chain.from_iterable(genres))
        
    def getAlbumGenre(self):
        '''Returns the Genre of the Album'''
        album = self.sp.albums([self.album_uri])
        self.req = self.req + 1
        return album['albums'][0]['genres']   
    
    def processArtistName(self, artist):
        '''Returns the exact name of the track by removing appended details
           This makes it possible to fetch the lyrics from Genius API by passing the track title
           as the API returns a null result if the track title is passed along with other appended details
        '''
        title = re.sub(r'\(.*?\)', "", title)
        title = title.split('-')[0]
        return title.strip()
    
    def getArtistCountry(self, songlang, artist_url):
        '''Return the country of the artist
           If the song language is not in English, then set language country as the country of the artist
           Else use the first four sentences of the artist bio to detect the country
           Since the information about the nationality is present in the first four-five lines of the biography      
        '''
        country = ''
        if songlang != "English":
            country = songlang
        else:
        #Use the artist url to scrape the Artist biography from Genius
            if artist_url:
                artist_info = self.scrape_artist_bio(artist_url)

                if artist_info:
                    splitText = artist_info.split('.')
                    length = len(splitText)
                    shortText = None
                    if length >= 1:
                        shortText = splitText[0]
                    if length > 2:
                        shortText = shortText + ". " +  splitText[1]
                    if length > 3:
                        shortText = shortText + ". " +  splitText[2]

                    if shortText:
                        nlp = en_core_web_sm.load()
                        doc = nlp(shortText)
                        st = ''
                        for ent in doc.ents:
                            if ent.label_ == "NORP":
                                return ent.text
                            elif ent.label_ == "GPE":
                                st = st + ent.text + ', '
                        country = st[0:-2]

        return country

# %%
def main():
    
    lyrics = []    
    tracks = []    
    trackLyrics = dict()    
    f1 = open("lyrics.txt-61", "w+")
    
    
    #Import the songs data into a dataframe
    songResults = pd.read_csv('results_id_queries.csv')

    sn = songResults[1:6]
    
    #Iterate over the rows of the dataframe
    for label, value in sn.iterrows():
        print(label)
        featuresDict = OrderedDict()
        track_info = None
        song_url = None
        artist_url = None
        track_lyrics = None
        artist_info = None
        songlang = None
        lyrics_state = None
        start_time = time()
        trackUri = value['uri']
        trackid = trackUri.split(":")[-1]
        #Create an instance of the trackInfo class
        trackInfo = TrackInfo(trackUri)
        
        # Add values from dataframe to the dictionary
        featuresDict['track_uri'] = trackUri
        featuresDict['music_title'] = value['music.title']
        featuresDict['music_artist'] = value['music.artist']
        featuresDict['music_album'] = value['music.album']
        featuresDict['found_title_spotify'] = trackInfo.title
        featuresDict['found_album_spotify'] = trackInfo.album
        featuresDict['found_artist_spotify'] = trackInfo.artist
        
        #Get the cleaned track title by removing appended details in brackets and albumName.
        #Split the string on  '-' and pass the first token in the call which is the actual title
        trackTitle = trackInfo.processTrackName(trackInfo.title, trackInfo.album)
        
        #Make a call to Genius and retrive matches of title-artist combination in the genius lyrics database
        geniusResponse = trackInfo.fetch_lyrics_page(trackTitle, trackInfo.artist)    
    
        #Genius call returns the best possible matches. Find the title-artist that best matched spotify input title-artist
        matchedTrack = trackInfo.findResponseMatch(geniusResponse, trackInfo.artist, trackInfo.title, trackInfo.album)
     
        #If a match is found in genius, fetch the track and artist url from the response
        #Lyrics State specifices if the lyrics is complete
        if matchedTrack:
            song_url = matchedTrack['url']
            artist_url = matchedTrack['primary_artist']['url']
            lyrics_state = matchedTrack['lyrics_state']
            
        #Store the urls in the dictionary
        if artist_url:
            featuresDict['genius_artist_url'] = artist_url
        #Use the song url to scrape the lyrics page from Genius
        if song_url:
            featuresDict['genius_track_url'] = song_url
            featuresDict['lyrics_state'] = lyrics_state
            #Retrieve the lyrics, track title, artist and album name as found in Genius
            geniusInfo = trackInfo.scrape_lyrics_artist_title(song_url)
        
            #Store the results in a dictionary
            #If lyrics is found, create a value as "lyrics:trackid and store it in trackDict
            #Store the text of the lyrics in a separate dictionary which is finally stored in a json file
            
            if geniusInfo:
                track_lyrics = geniusInfo[0]
                trackLyrics['lyrics:'+trackid] = track_lyrics
                trackInfo.trackDict['lyricsId'] = 'lyrics:'+trackid
            
                if geniusInfo[1]:
                    featuresDict['found_genius_title'] = geniusInfo[1]
                if geniusInfo[2]:
                    featuresDict['found_genius_artist'] = geniusInfo[2]
                if geniusInfo[3]:
                    featuresDict['other_track_info'] = geniusInfo[3]

        #Detect the language of the lyrics
        if track_lyrics:
            songlang = trackInfo.getTrackLanguage(track_lyrics)
            featuresDict['lyrics_language'] = songlang
            
        #Get the country of the Artist 
        country =  trackInfo.getArtistCountry(songlang, artist_url)
        featuresDict['artist_country'] = country
     
        #Get the album and artist genres and store in a dictionary
        artistGenres = trackInfo.getArtistGenre()
        sleep(randint(2,4))
        albumGenres = trackInfo.getAlbumGenre()
        featuresDict['artist_genres'] = str(artistGenres)
        featuresDict['album_genres'] = str(albumGenres)
        
        #Add the metadata dictionary to the ordered dictionary
        featuresDict.update(trackInfo.trackDict)
        
        #Store the audio analysis url in the dictionary
        featuresDict['analysis_url'] = 'https://api.spotify.com/v1/audio-analysis/' + trackid
        
        #Find audio features of the track and merge with the trackDict
        features = trackInfo.getAudioFeatures()
        if features:
            featuresDict.update(features[0])
        
        tracks.append(featuresDict)
        

        #Calculate the request frequency per second
        req = trackInfo.req
        elapsed_time = time() - start_time
        print('label:' + str(label))
        print('Requests:{}; Frequency: {} requests/s'.format(req, req/elapsed_time))
        clear_output(wait = True)
        
        #Enforce Rate limit
        #Pause the loop
        sleep(randint(10,15))

        # Break the loop if the number of requests is greater than expected
        if req > 17:
            print(label)
            print('Number of requests was greater than expected.')
            break

    lyrics.append(trackLyrics)
    json.dump(lyrics, f1)
    df = pd.DataFrame.from_dict(tracks)
    df.to_csv("songs_data1-61.csv", index=False)
    #print(df)
    f1.close()

main()
# Out:
# 5
# label:5
# Requests:7; Frequency: 0.9878492381750655 requests/s

# %%
songResults = pd.read_csv('results_id_queries.csv')
pd.options.display.max_columns = None
display(songResults)
# Out:
#                                         uri  \
# 0      spotify:track:5JiLJJbuA92jnPoQJ7WhkK
# 1      spotify:track:1vScEbMXJslS5xx5noo0Ch
# 2      spotify:track:0RMtbz2AKZXMAL4cP0tXRm
# 3      spotify:track:4LzfByj2wTGZRjr8szwcFD
# 4      spotify:track:3QquT92Ti51799zeBywMOj
# 5      spotify:track:2ce5n5MpJQgvnAHtmfxS1C
# 6      spotify:track:43k8fgVQhZYZ6Mt6LtRnQw
# 7      spotify:track:5v26uKaXYsWRwWF21WVB3S
# 8      spotify:track:7iWWmsgELL98538Gxs6Wu7
# 9      spotify:track:70injMLRxsQgcRX54Vkxyz
# 10     spotify:track:0GATmBanwPiHQBfl2mDq3o
# 11     spotify:track:4oevcaqqQpR85Qmp6LqCzK
# 12     spotify:track:0AQ4a4Evmy00wyksgYS2WM
# 13     spotify:track:1QEbrQlmtYVc8l6udxhwhF
# 14     spotify:track:1NgaWRYfMtTls3OiXNaGus
# 15     spotify:track:63JD6EIQPwXMPlYCuGtXUl
# 16     spotify:track:654YntfsU6il9PX173dpuD
# 17     spotify:track:5jEipVlHWNICDhtMed5syi
# 18     spotify:track:7tu6IpmSey65T1TLcViLuQ
# 19     spotify:track:26HMjtnUHasPqQVvo38Wlw
# 20     spotify:track:0UFtsK5aSrq5zYai4aikAu
# 21     spotify:track:54xvAdU6A4HZSUac2CFtUn
# 22     spotify:track:79iGIEA5PpbkcOeqwRKBtj
# 23     spotify:track:1Bu1nVp4rWu7tQFZghpN29
# 24     spotify:track:1Wyo20oMjhSYX9IBstBoKT
# 25     spotify:track:67j4DNda2VS83bQY4OUR97
# 26     spotify:track:7LwNbU51jSENXgwkPXagKE
# 27     spotify:track:0LI4BP3JHQw0I0bFwGeiQ3
# 28     spotify:track:0jJ7AZj9ZDPTcofANqNB6f
# 29     spotify:track:2qRVadW0yxjNHooky898Nm
# ...                                     ...
# 63618  spotify:track:31EJcKUZGaDCm684ByEx0G
# 63619  spotify:track:25GRgMoXezppQjLjSDLKf5
# 63620  spotify:track:4hGKMuDQCgWxX7gF8kwJtr
# 63621  spotify:track:0VkOpoN1xFZPHW0eyC0yTG
# 63622  spotify:track:5znEiVKJITQ1JProGoHht6
# 63623  spotify:track:0CZQNI3Evb4Nd8GeU49LFj
# 63624  spotify:track:6gTdrud3duWIBg8r2YdjOL
# 63625  spotify:track:0u5coU84PCSN4t8jZwYUAp
# 63626  spotify:track:2hOc4ZFuRUFcuDk1aCz7Gk
# 63627  spotify:track:4h64A3xWnYzPR72zUhJKo1
# 63628  spotify:track:4maH3qPU16vglvl0gSIJMO
# 63629  spotify:track:5L8V6TPunEUj98IvXdhDU5
# 63630  spotify:track:5vczxprsg5zJWOlR7gTxEX
# 63631  spotify:track:6PpSq6Eb9wE0HUD5kPQ7oP
# 63632  spotify:track:5w2zI2TnxiP4DMcsA0P30M
# 63633  spotify:track:2pmHkc7h9gPjKEb7bYeRBx
# 63634  spotify:track:7obN7CIn2WQqXEzXx612sk
# 63635  spotify:track:3p4gKJtHQN3chcj3PhXKAh
# 63636  spotify:track:0HEEAuKXY3wOzFtRq6Gz6g
# 63637  spotify:track:7yhdrrz7dvsqTAdcUqzPSN
# 63638  spotify:track:0LuNSgpNYWPoEGkRaGvYrJ
# 63639  spotify:track:6QJYxTKD0rMGtq94WV4ADu
# 63640  spotify:track:0itNMuBHye9fu392b4e9oa
# 63641  spotify:track:5e0Q4X1HKFBFt3omsWVgNd
# 63642  spotify:track:3d90L14szDmAY033F1jKwI
# 63643  spotify:track:5XFzqvGBZBy7rGvAndj0uJ
# 63644  spotify:track:2UevXnfjokONZQ437u21jS
# 63645  spotify:track:2uGWFmJYpJMUNhzG1Zg6LN
# 63646  spotify:track:5aYozSl90qcFiyj740XrEV
# 63647  spotify:track:1jrARDhheF2nrDEevG9rmo
#
#                                       music.artist  \
# 0                             Stadiumx,Taylr Renee
# 1                           Michael Feiner & Caisa
# 2                                             MOTi
# 3               Orjan Nilsen & Jonathan Mendelsohn
# 4                        Paris Blohm & Taylr Renee
# 5                                    Pierce Fulton
# 6                                         Quintino
# 7                                      Knife Party
# 8                           R3hab & Trevor Guthrie
# 9                                        Row Rocka
# 10     Steve Aoki, Diplo & Deorro feat. Steve Bays
# 11                                       <unknown>
# 12                    DJ KUBA & NEITAN x Paul Dave
# 13                                      Toby Green
# 14                                 FTampa & Felguk
# 15                               HIFI & John Lakke
# 16                          Laidback Luke & Tujamo
# 17                                        Tom Fall
# 18                                      Pep & Rash
# 19                                        Quintino
# 20                                       Astronaut
# 21                           Carlprit Feat. Jaicko
# 22                                         Juventa
# 23                                   Marc Benjamin
# 24                                           Siege
# 25                                     Vida, JAKKO
# 26                                Sick Individuals
# 27                       Vicetone feat. Kat Nestel
# 28                         Blasterjaxx, Badd Dimes
# 29                                       Kraftklub
# ...                                            ...
# 63618                        Red Hot Chili Peppers
# 63619                                    Nicky Jam
# 63620                                Jones & Brock
# 63621                                Sons Of Maria
# 63622                                     Synapson
# 63623                        Red Hot Chili Peppers
# 63624                        Red Hot Chili Peppers
# 63625                                      Gaullin
# 63626                               David Carreira
# 63627                                     Felicity
# 63628                                     Synapson
# 63629                                 Alex Luciano
# 63630                                      Ehrling
# 63631                                Sons Of Maria
# 63632                                 Ours Samplus
# 63633                                     Synapson
# 63634                                  Mellow Mood
# 63635                                         Gala
# 63636                                   Izzamuzzic
# 63637                                     Synapson
# 63638                                  Triana Park
# 63639                               Maverick Sabre
# 63640                        Red Hot Chili Peppers
# 63641                                     Synapson
# 63642                                    Fil Tilen
# 63643                                  Mellow Mood
# 63644                                   Clem Beatz
# 63645                                     Claptone
# 63646                                  Mellow Mood
# 63647                        Red Hot Chili Peppers
#
#                                          music.album  \
# 0                                   Howl At The Moon
# 1                                            Save Me
# 2                                   Don't Go Lose It
# 3                                Apart - The Remixes
# 4                              Left Behinds - Single
# 5                                              Kuaga
# 6                                            Go Hard
# 7                                       Abandon Ship
# 8                                          SoundWave
# 9                                           Kingwood
# 10                 Freak (feat. Steve Bays) - Single
# 11                                              2015
# 12                                              2015
# 13                                              2015
# 14                                   Carry The Beats
# 15                     How To Break A Heart - Single
# 16                                            S.A.X.
# 17          One For Love (Carl Nunes Remix) - Single
# 18                                            Rumors
# 19                                            Winner
# 20                Champions (feat. Harry Brooks Jnr)
# 21                                Remember to Forget
# 22                           quality-dance-music.com
# 23     Revealed Recordings presents ADE Sampler 2014
# 24                           quality-dance-music.com
# 25                           quality-dance-music.com
# 26                                           Skyline
# 27                                        No Way Out
# 28                                             Titan
# 29                                        In Schwarz
# ...                                              ...
# 63618                Stadium Arcadium (U.S. Version)
# 63619                                 Nicky Jam Hits
# 63620                          Join Me (feat. Anica)
# 63621                                       With You
# 63622                   Convergence (Deluxe Edition)
# 63623                Stadium Arcadium (U.S. Version)
# 63624                Stadium Arcadium (U.S. Version)
# 63625                                  Sun Goes Down
# 63626                                           1991
# 63627                                       Together
# 63628                   Convergence (Deluxe Edition)
# 63629                                      Landscape
# 63630                                 Give Me Summer
# 63631                                  Chunga Changa
# 63632                                         Isteri
# 63633                   Convergence (Deluxe Edition)
# 63634                                    2 the World
# 63635                              Freed From Desire
# 63636                                         Leeloo
# 63637                   Convergence (Deluxe Edition)
# 63638                          Line (Stan Sax Remix)
# 63639                                 I Need (Remix)
# 63640                Stadium Arcadium (U.S. Version)
# 63641                   Convergence (Deluxe Edition)
# 63642                                 Ko Vam Je Reko
# 63643                                    2 the World
# 63644                                       Daydream
# 63645                                        Charmer
# 63646                                    2 the World
# 63647                Stadium Arcadium (U.S. Version)
#
#                                              music.title  \
# 0                        Howl At The Moon (Original Mix)
# 1                                  Save Me (Jakko Remix)
# 2                        Don't Go Lose It (Original Mix)
# 3              Apart (Martin Volt & Quentin State Remix)
# 4                              Left Behinds (Radio Edit)
# 5                                     Kuaga (Radio Edit)
# 6                                 Go Hard (Original Mix)
# 7                                             Give It Up
# 8                                 SoundWave (Radio Edit)
# 9                                Kingwood (Original Mix)
# 10                                                 Freak
# 11                          Arno Cost & Arias - At Night
# 12                                Gangsta (Original Mix)
# 13                                  Raven (Original Mix)
# 14                                   Slap (Original Mix)
# 15                                  How To Break A Heart
# 16                                   S.A.X. (Radio Edit)
# 17                       One For Love (Carl Nunes Remix)
# 18                                   Rumors (Radio Edit)
# 19                                   Winner (Radio Edit)
# 20                    Champions (feat. Harry Brooks Jnr)
# 21       Remember to Forget (Michael Mind Project Remix)
# 22       SHWDWN (Original Mix) [quality-dance-music.com]
# 23                             The Center (Original Mix)
# 24     Liberty City (Original Mix) [quality dance music]
# 25           Amazon (Original Mix) [quality dance music]
# 26                                Skyline (Original Mix)
# 27                               No Way Out (Radio Edit)
# 28                                  Titan (Original Mix)
# 29                                           Unsere Fans
# ...                                                  ...
# 63618                                    She Looks To Me
# 63619                                        Voy a Beber
# 63620                              Join Me (feat. Anica)
# 63621                            With You - Original Mix
# 63622                       Fireball (feat. Broken Back)
# 63623                                         C'mon Girl
# 63624                                          So Much I
# 63625                                      Sun Goes Down
# 63626                                              Lucia
# 63627                                           Together
# 63628                                    Around Midnight
# 63629                           Landscape - Original Mix
# 63630                                         Palm Trees
# 63631                  Chunga Changa - Original Club Mix
# 63632                                       Spell on You
# 63633  Fireball - feat. Broken Back [Synapson Re-vision]
# 63634                                Inna Jamaica, Pt. 2
# 63635             Freed From Desire - Mr. Jack Club Edit
# 63636                                             Aromat
# 63637                       Control - feat. Sirius Trema
# 63638                              Line (Stan Sax Remix)
# 63639                  I Need (Remix) - Extended Version
# 63640                                       Tell Me Baby
# 63641             Going Back To My Roots (feat. Tessa B)
# 63642                                     Ko Vam Je Reko
# 63643                                       Bun Mi Heart
# 63644                                           Daydream
# 63645                                          Heartbeat
# 63646                                          Even Over
# 63647                                           Warlocks
#
#                                  found_with_artist    found_with_album  \
# 0                                              NaN    Howl At The Moon
# 1                                              NaN                 NaN
# 2                                              NaN                 NaN
# 3               Orjan Nilsen & Jonathan Mendelsohn                 NaN
# 4                        Paris Blohm & Taylr Renee                 NaN
# 5                                              NaN                 NaN
# 6                                              NaN             Go Hard
# 7                                              NaN                 NaN
# 8                           R3hab & Trevor Guthrie           SoundWave
# 9                                              NaN                 NaN
# 10     Steve Aoki, Diplo & Deorro feat. Steve Bays                 NaN
# 11                                             NaN                2015
# 12                                             NaN                2015
# 13                                             NaN                2015
# 14                                 FTampa & Felguk                 NaN
# 15                               HIFI & John Lakke                 NaN
# 16                          Laidback Luke & Tujamo              S.A.X.
# 17                                        Tom Fall                 NaN
# 18                                             NaN                 NaN
# 19                                             NaN                 NaN
# 20                                             NaN                 NaN
# 21                                             NaN  Remember to Forget
# 22                                         Juventa                 NaN
# 23                                   Marc Benjamin                 NaN
# 24                                           Siege                 NaN
# 25                                     Vida, JAKKO                 NaN
# 26                                             NaN                 NaN
# 27                                             NaN                 NaN
# 28                                             NaN               Titan
# 29                                       Kraftklub                 NaN
# ...                                            ...                 ...
# 63618                        Red Hot Chili Peppers                 NaN
# 63619                                          NaN                 NaN
# 63620                                          NaN                 NaN
# 63621                                          NaN                 NaN
# 63622                                          NaN                 NaN
# 63623                        Red Hot Chili Peppers                 NaN
# 63624                        Red Hot Chili Peppers                 NaN
# 63625                                          NaN                 NaN
# 63626                                          NaN                1991
# 63627                                          NaN                 NaN
# 63628                                          NaN                 NaN
# 63629                                          NaN                 NaN
# 63630                                          NaN                 NaN
# 63631                                          NaN                 NaN
# 63632                                          NaN                 NaN
# 63633                                          NaN                 NaN
# 63634                                          NaN                 NaN
# 63635                                          NaN                 NaN
# 63636                                          NaN                 NaN
# 63637                                          NaN                 NaN
# 63638                                          NaN                 NaN
# 63639                                          NaN      I Need (Remix)
# 63640                        Red Hot Chili Peppers                 NaN
# 63641                                          NaN                 NaN
# 63642                                          NaN                 NaN
# 63643                                          NaN                 NaN
# 63644                                          NaN                 NaN
# 63645                                          NaN                 NaN
# 63646                                          NaN                 NaN
# 63647                        Red Hot Chili Peppers                 NaN
#
#                                         found_with_title album.album_type  \
# 0                        Howl At The Moon (Original Mix)           single
# 1                                                    NaN           single
# 2                                                    NaN           single
# 3              Apart (Martin Volt & Quentin State Remix)           single
# 4                              Left Behinds (Radio Edit)           single
# 5                                                    NaN           single
# 6                                 Go Hard (Original Mix)      compilation
# 7                                                    NaN            album
# 8                                 SoundWave (Radio Edit)           single
# 9                                                    NaN           single
# 10                                                 Freak            album
# 11                          Arno Cost & Arias - At Night            album
# 12                                Gangsta (Original Mix)      compilation
# 13                                  Raven (Original Mix)           single
# 14                                   Slap (Original Mix)           single
# 15                                  How To Break A Heart           single
# 16                                   S.A.X. (Radio Edit)           single
# 17                       One For Love (Carl Nunes Remix)      compilation
# 18                                                   NaN           single
# 19                                                   NaN           single
# 20                                                   NaN           single
# 21       Remember to Forget (Michael Mind Project Remix)           single
# 22       SHWDWN (Original Mix) [quality-dance-music.com]      compilation
# 23                             The Center (Original Mix)            album
# 24     Liberty City (Original Mix) [quality dance music]            album
# 25           Amazon (Original Mix) [quality dance music]            album
# 26                                                   NaN           single
# 27                                                   NaN           single
# 28                                  Titan (Original Mix)           single
# 29                                           Unsere Fans            album
# ...                                                  ...              ...
# 63618                                    She Looks To Me            album
# 63619                                                NaN            album
# 63620                                                NaN           single
# 63621                                                NaN           single
# 63622                                                NaN            album
# 63623                                         C'mon Girl            album
# 63624                                          So Much I            album
# 63625                                                NaN           single
# 63626                                              Lucia            album
# 63627                                                NaN           single
# 63628                                                NaN            album
# 63629                                                NaN           single
# 63630                                                NaN           single
# 63631                                                NaN           single
# 63632                                                NaN            album
# 63633                                                NaN            album
# 63634                                                NaN            album
# 63635                                                NaN           single
# 63636                                                NaN           single
# 63637                                                NaN            album
# 63638                                                NaN           single
# 63639                  I Need (Remix) - Extended Version            album
# 63640                                       Tell Me Baby            album
# 63641                                                NaN            album
# 63642                                                NaN           single
# 63643                                                NaN            album
# 63644                                                NaN           single
# 63645                                                NaN            album
# 63646                                                NaN            album
# 63647                                           Warlocks            album
#
#                                            album.artists  \
# 0      [{u'name': u'Driftmoon', u'external_urls': {u'...
# 1      [{u'name': u'Michael Feiner & Caisa', u'extern...
# 2      [{u'name': u'MOTi', u'external_urls': {u'spoti...
# 3      [{u'name': u'Orjan Nilsen', u'external_urls': ...
# 4      [{u'name': u'Paris Blohm', u'external_urls': {...
# 5      [{u'name': u'Pierce Fulton', u'external_urls':...
# 6      [{u'name': u'Various Artists', u'external_urls...
# 7      [{u'name': u'Knife Party', u'external_urls': {...
# 8      [{u'name': u'R3HAB', u'external_urls': {u'spot...
# 9      [{u'name': u'Row Rocka', u'external_urls': {u'...
# 10     [{u'name': u'Diplo', u'external_urls': {u'spot...
# 11     [{u'name': u'Nicky Romero', u'external_urls': ...
# 12     [{u'name': u'Various Artists', u'external_urls...
# 13     [{u'name': u'by RAVEN', u'external_urls': {u's...
# 14     [{u'name': u'FTampa', u'external_urls': {u'spo...
# 15     [{u'name': u'Hifi', u'external_urls': {u'spoti...
# 16     [{u'name': u'Laidback Luke', u'external_urls':...
# 17     [{u'name': u'Gareth Emery', u'external_urls': ...
# 18     [{u'name': u'Pep & Rash', u'external_urls': {u...
# 19     [{u'name': u'Quintino', u'external_urls': {u's...
# 20     [{u'name': u'Astronaut', u'external_urls': {u'...
# 21     [{u'name': u'Carlprit', u'external_urls': {u's...
# 22     [{u'name': u'Various Artists', u'external_urls...
# 23     [{u'name': u'Thomas Newson', u'external_urls':...
# 24     [{u'name': u'Nicky Romero', u'external_urls': ...
# 25     [{u'name': u'Nicky Romero', u'external_urls': ...
# 26     [{u'name': u'Sick Individuals', u'external_url...
# 27     [{u'name': u'Vicetone', u'external_urls': {u's...
# 28     [{u'name': u'Frequencerz', u'external_urls': {...
# 29     [{u'name': u'Kraftklub', u'external_urls': {u'...
# ...                                                  ...
# 63618  [{u'name': u'Red Hot Chili Peppers', u'externa...
# 63619  [{u'name': u'Nicky Jam', u'external_urls': {u'...
# 63620  [{u'name': u'Jones & Brock', u'external_urls':...
# 63621  [{u'name': u'Sons Of Maria', u'external_urls':...
# 63622  [{u'name': u'Synapson', u'external_urls': {u's...
# 63623  [{u'name': u'Red Hot Chili Peppers', u'externa...
# 63624  [{u'name': u'Red Hot Chili Peppers', u'externa...
# 63625  [{u'name': u'Gaullin', u'external_urls': {u'sp...
# 63626  [{u'name': u'Lucia Popp', u'external_urls': {u...
# 63627  [{u'name': u'Felicity', u'external_urls': {u's...
# 63628  [{u'name': u'Synapson', u'external_urls': {u's...
# 63629  [{u'name': u'Alex Luciano', u'external_urls': ...
# 63630  [{u'name': u'Ehrling', u'external_urls': {u'sp...
# 63631  [{u'name': u'Sons Of Maria', u'external_urls':...
# 63632  [{u'name': u'Ours Samplus', u'external_urls': ...
# 63633  [{u'name': u'Synapson', u'external_urls': {u's...
# 63634  [{u'name': u'Mellow Mood', u'external_urls': {...
# 63635  [{u'name': u'Gala', u'external_urls': {u'spoti...
# 63636  [{u'name': u'Izzamuzzic', u'external_urls': {u...
# 63637  [{u'name': u'Synapson', u'external_urls': {u's...
# 63638  [{u'name': u'Triana Park', u'external_urls': {...
# 63639  [{u'name': u'Daniel Moss', u'external_urls': {...
# 63640  [{u'name': u'Red Hot Chili Peppers', u'externa...
# 63641  [{u'name': u'Synapson', u'external_urls': {u's...
# 63642  [{u'name': u'Fil Tilen', u'external_urls': {u'...
# 63643  [{u'name': u'Mellow Mood', u'external_urls': {...
# 63644  [{u'name': u'Clem Beatz', u'external_urls': {u...
# 63645  [{u'name': u'Claptone', u'external_urls': {u's...
# 63646  [{u'name': u'Mellow Mood', u'external_urls': {...
# 63647  [{u'name': u'Red Hot Chili Peppers', u'externa...
#
#                                  album.available_markets  \
# 0      [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 1      [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 2      [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 3      [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 4      [AE, AR, BE, BG, BH, BO, BR, CA, CH, CL, CO, C...
# 5      [AD, AE, AR, AU, BE, BG, BH, BO, BR, CA, CL, C...
# 6                                               [CA, US]
# 7                                               [CA, US]
# 8      [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 9      [AD, AE, AR, BE, BG, BH, BO, BR, CA, CL, CO, C...
# 10     [AD, AE, AR, AT, BE, BG, BH, BO, BR, CA, CH, C...
# 11     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 12     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 13     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 14     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 15     [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 16     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 17                                              [CA, US]
# 18     [AD, AE, AR, AT, BG, BO, CA, CH, CL, CO, CR, C...
# 19     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 20     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 21     [AE, AR, AU, BG, BH, BO, BR, CA, CH, CL, CO, C...
# 22     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 23     [AD, AE, AR, BE, BG, BH, BO, BR, CA, CL, CO, C...
# 24     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 25     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 26     [AD, AE, AR, AT, BE, BG, BH, BO, BR, CA, CH, C...
# 27     [AD, AE, AR, AT, BE, BG, BO, CA, CH, CL, CO, C...
# 28     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 29     [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# ...                                                  ...
# 63618  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63619  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63620  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63621  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63622  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63623  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63624  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63625  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63626  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63627                                                 []
# 63628  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63629  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63630  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63631  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63632  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63633  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63634  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63635  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63636  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63637  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63638  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63639  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63640  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63641  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63642  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63643  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63644  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63645                                           [CA, US]
# 63646  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 63647  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
#
#                              album.external_urls.spotify  \
# 0      https://open.spotify.com/album/41lOgCG3vkatLYm...
# 1      https://open.spotify.com/album/47jG5To8nD0OF54...
# 2      https://open.spotify.com/album/6hIm6DZEfvCDRhK...
# 3      https://open.spotify.com/album/4cVG3FZnUZ2zUzS...
# 4      https://open.spotify.com/album/58Yj90JFPXPIUaK...
# 5      https://open.spotify.com/album/6LHdKCyGDEgKGX3...
# 6      https://open.spotify.com/album/4jMLTMDOASfmSfS...
# 7      https://open.spotify.com/album/3isR1GYMYEQhDv8...
# 8      https://open.spotify.com/album/5QxCZF6rgL45zDd...
# 9      https://open.spotify.com/album/1rsli5yy8dpSZe9...
# 10     https://open.spotify.com/album/4c7lxBZCbR8SQso...
# 11     https://open.spotify.com/album/64VVBooplZLb1Ln...
# 12     https://open.spotify.com/album/1hkw3Qu5SrqrJF2...
# 13     https://open.spotify.com/album/3IthvmestrdJ6UD...
# 14     https://open.spotify.com/album/7IxOKyWWmcM1vdp...
# 15     https://open.spotify.com/album/2kTJz5jeDJInFHI...
# 16     https://open.spotify.com/album/6FpVmDQyDahn9hc...
# 17     https://open.spotify.com/album/3vzzmt79LTBIbO8...
# 18     https://open.spotify.com/album/4aCkJNfpUzuqXCI...
# 19     https://open.spotify.com/album/3PWkgBpTSVfNGl2...
# 20     https://open.spotify.com/album/00dChL0fGKRK3Ou...
# 21     https://open.spotify.com/album/6wWiV9IYOI6YBqX...
# 22     https://open.spotify.com/album/7rx9rT8VP8zAcRh...
# 23     https://open.spotify.com/album/74beNDhngL6rPdp...
# 24     https://open.spotify.com/album/7CRSiZY32HKao3H...
# 25     https://open.spotify.com/album/7CRSiZY32HKao3H...
# 26     https://open.spotify.com/album/7uQlrvD22AiP21Y...
# 27     https://open.spotify.com/album/356O3fpYdCew0Gf...
# 28     https://open.spotify.com/album/0a89dFlTNGX3Mrx...
# 29     https://open.spotify.com/album/30t7VjbwgOEPY1A...
# ...                                                  ...
# 63618  https://open.spotify.com/album/7xl50xr9NDkd3i2...
# 63619  https://open.spotify.com/album/4etANPc5BMELu5y...
# 63620  https://open.spotify.com/album/0m9OPLqG1e4kmmf...
# 63621  https://open.spotify.com/album/0vxuRacZHB3iN3r...
# 63622  https://open.spotify.com/album/1qZyM5DozaVtdrR...
# 63623  https://open.spotify.com/album/7xl50xr9NDkd3i2...
# 63624  https://open.spotify.com/album/7xl50xr9NDkd3i2...
# 63625  https://open.spotify.com/album/5dzg6ra45xAvgnj...
# 63626  https://open.spotify.com/album/0IdWqtIvsvVm9Cs...
# 63627  https://open.spotify.com/album/0nVOvsHxC7U7g0y...
# 63628  https://open.spotify.com/album/1qZyM5DozaVtdrR...
# 63629  https://open.spotify.com/album/4zqFyPkCTcaPBf8...
# 63630  https://open.spotify.com/album/6vnTasm05jeY3iZ...
# 63631  https://open.spotify.com/album/0siUjYY92ZFhp6q...
# 63632  https://open.spotify.com/album/5J3L8ukBVqikwoS...
# 63633  https://open.spotify.com/album/1qZyM5DozaVtdrR...
# 63634  https://open.spotify.com/album/71Z4V79RLI7DdKM...
# 63635  https://open.spotify.com/album/3NtqSRu4zoyCUQ7...
# 63636  https://open.spotify.com/album/33B1oe6xFzKB8w6...
# 63637  https://open.spotify.com/album/1qZyM5DozaVtdrR...
# 63638  https://open.spotify.com/album/6BqNAwJyKkz59EQ...
# 63639  https://open.spotify.com/album/3xyEIhMFhaVW3dh...
# 63640  https://open.spotify.com/album/7xl50xr9NDkd3i2...
# 63641  https://open.spotify.com/album/1qZyM5DozaVtdrR...
# 63642  https://open.spotify.com/album/0H8Qz4f75jjsQaA...
# 63643  https://open.spotify.com/album/71Z4V79RLI7DdKM...
# 63644  https://open.spotify.com/album/6kZOwjHj6PgaqEJ...
# 63645  https://open.spotify.com/album/6QLRh3cxDFW1kzX...
# 63646  https://open.spotify.com/album/71Z4V79RLI7DdKM...
# 63647  https://open.spotify.com/album/7xl50xr9NDkd3i2...
#
#                                               album.href  \
# 0      https://api.spotify.com/v1/albums/41lOgCG3vkat...
# 1      https://api.spotify.com/v1/albums/47jG5To8nD0O...
# 2      https://api.spotify.com/v1/albums/6hIm6DZEfvCD...
# 3      https://api.spotify.com/v1/albums/4cVG3FZnUZ2z...
# 4      https://api.spotify.com/v1/albums/58Yj90JFPXPI...
# 5      https://api.spotify.com/v1/albums/6LHdKCyGDEgK...
# 6      https://api.spotify.com/v1/albums/4jMLTMDOASfm...
# 7      https://api.spotify.com/v1/albums/3isR1GYMYEQh...
# 8      https://api.spotify.com/v1/albums/5QxCZF6rgL45...
# 9      https://api.spotify.com/v1/albums/1rsli5yy8dpS...
# 10     https://api.spotify.com/v1/albums/4c7lxBZCbR8S...
# 11     https://api.spotify.com/v1/albums/64VVBooplZLb...
# 12     https://api.spotify.com/v1/albums/1hkw3Qu5Srqr...
# 13     https://api.spotify.com/v1/albums/3IthvmestrdJ...
# 14     https://api.spotify.com/v1/albums/7IxOKyWWmcM1...
# 15     https://api.spotify.com/v1/albums/2kTJz5jeDJIn...
# 16     https://api.spotify.com/v1/albums/6FpVmDQyDahn...
# 17     https://api.spotify.com/v1/albums/3vzzmt79LTBI...
# 18     https://api.spotify.com/v1/albums/4aCkJNfpUzuq...
# 19     https://api.spotify.com/v1/albums/3PWkgBpTSVfN...
# 20     https://api.spotify.com/v1/albums/00dChL0fGKRK...
# 21     https://api.spotify.com/v1/albums/6wWiV9IYOI6Y...
# 22     https://api.spotify.com/v1/albums/7rx9rT8VP8zA...
# 23     https://api.spotify.com/v1/albums/74beNDhngL6r...
# 24     https://api.spotify.com/v1/albums/7CRSiZY32HKa...
# 25     https://api.spotify.com/v1/albums/7CRSiZY32HKa...
# 26     https://api.spotify.com/v1/albums/7uQlrvD22AiP...
# 27     https://api.spotify.com/v1/albums/356O3fpYdCew...
# 28     https://api.spotify.com/v1/albums/0a89dFlTNGX3...
# 29     https://api.spotify.com/v1/albums/30t7VjbwgOEP...
# ...                                                  ...
# 63618  https://api.spotify.com/v1/albums/7xl50xr9NDkd...
# 63619  https://api.spotify.com/v1/albums/4etANPc5BMEL...
# 63620  https://api.spotify.com/v1/albums/0m9OPLqG1e4k...
# 63621  https://api.spotify.com/v1/albums/0vxuRacZHB3i...
# 63622  https://api.spotify.com/v1/albums/1qZyM5DozaVt...
# 63623  https://api.spotify.com/v1/albums/7xl50xr9NDkd...
# 63624  https://api.spotify.com/v1/albums/7xl50xr9NDkd...
# 63625  https://api.spotify.com/v1/albums/5dzg6ra45xAv...
# 63626  https://api.spotify.com/v1/albums/0IdWqtIvsvVm...
# 63627  https://api.spotify.com/v1/albums/0nVOvsHxC7U7...
# 63628  https://api.spotify.com/v1/albums/1qZyM5DozaVt...
# 63629  https://api.spotify.com/v1/albums/4zqFyPkCTcaP...
# 63630  https://api.spotify.com/v1/albums/6vnTasm05jeY...
# 63631  https://api.spotify.com/v1/albums/0siUjYY92ZFh...
# 63632  https://api.spotify.com/v1/albums/5J3L8ukBVqik...
# 63633  https://api.spotify.com/v1/albums/1qZyM5DozaVt...
# 63634  https://api.spotify.com/v1/albums/71Z4V79RLI7D...
# 63635  https://api.spotify.com/v1/albums/3NtqSRu4zoyC...
# 63636  https://api.spotify.com/v1/albums/33B1oe6xFzKB...
# 63637  https://api.spotify.com/v1/albums/1qZyM5DozaVt...
# 63638  https://api.spotify.com/v1/albums/6BqNAwJyKkz5...
# 63639  https://api.spotify.com/v1/albums/3xyEIhMFhaVW...
# 63640  https://api.spotify.com/v1/albums/7xl50xr9NDkd...
# 63641  https://api.spotify.com/v1/albums/1qZyM5DozaVt...
# 63642  https://api.spotify.com/v1/albums/0H8Qz4f75jjs...
# 63643  https://api.spotify.com/v1/albums/71Z4V79RLI7D...
# 63644  https://api.spotify.com/v1/albums/6kZOwjHj6Pga...
# 63645  https://api.spotify.com/v1/albums/6QLRh3cxDFW1...
# 63646  https://api.spotify.com/v1/albums/71Z4V79RLI7D...
# 63647  https://api.spotify.com/v1/albums/7xl50xr9NDkd...
#
#                      album.id  \
# 0      41lOgCG3vkatLYmpLZJjAW
# 1      47jG5To8nD0OF54tvuovxm
# 2      6hIm6DZEfvCDRhKlxHRUDB
# 3      4cVG3FZnUZ2zUzSjMTUUPi
# 4      58Yj90JFPXPIUaKc5sC8wb
# 5      6LHdKCyGDEgKGX3JkJUlMD
# 6      4jMLTMDOASfmSfSKmmasHo
# 7      3isR1GYMYEQhDv8DrzYjAI
# 8      5QxCZF6rgL45zDdaLrPQgZ
# 9      1rsli5yy8dpSZe9rCVlIF2
# 10     4c7lxBZCbR8SQsoVvO2lCb
# 11     64VVBooplZLb1LnwEiqAWL
# 12     1hkw3Qu5SrqrJF2ELpaqR8
# 13     3IthvmestrdJ6UDG0Rz84i
# 14     7IxOKyWWmcM1vdpstXjuim
# 15     2kTJz5jeDJInFHIo2vWieI
# 16     6FpVmDQyDahn9hcuJbKZJ3
# 17     3vzzmt79LTBIbO8uWP7ksr
# 18     4aCkJNfpUzuqXCIf53znYL
# 19     3PWkgBpTSVfNGl2KI2OVYA
# 20     00dChL0fGKRK3Ouc6szAe6
# 21     6wWiV9IYOI6YBqXeYSuGMf
# 22     7rx9rT8VP8zAcRhKva7zPn
# 23     74beNDhngL6rPdpbBp1fR6
# 24     7CRSiZY32HKao3H3pJg6NA
# 25     7CRSiZY32HKao3H3pJg6NA
# 26     7uQlrvD22AiP21Y8lItyh5
# 27     356O3fpYdCew0GfSGbNyo4
# 28     0a89dFlTNGX3Mrx56UO05x
# 29     30t7VjbwgOEPY1ATeIL44h
# ...                       ...
# 63618  7xl50xr9NDkd3i2kBbzsNZ
# 63619  4etANPc5BMELu5yx987Rpx
# 63620  0m9OPLqG1e4kmmfT1aprsg
# 63621  0vxuRacZHB3iN3rsL6ybk4
# 63622  1qZyM5DozaVtdrRrW7imrR
# 63623  7xl50xr9NDkd3i2kBbzsNZ
# 63624  7xl50xr9NDkd3i2kBbzsNZ
# 63625  5dzg6ra45xAvgnjBiUd51F
# 63626  0IdWqtIvsvVm9CsRyQ6jTQ
# 63627  0nVOvsHxC7U7g0y2nNjRxX
# 63628  1qZyM5DozaVtdrRrW7imrR
# 63629  4zqFyPkCTcaPBf8vUsYrkB
# 63630  6vnTasm05jeY3iZovBPPxO
# 63631  0siUjYY92ZFhp6q8ZdyCrJ
# 63632  5J3L8ukBVqikwoSN9Mv5sk
# 63633  1qZyM5DozaVtdrRrW7imrR
# 63634  71Z4V79RLI7DdKMAFoHfWG
# 63635  3NtqSRu4zoyCUQ7VRbH3f5
# 63636  33B1oe6xFzKB8w60uz98gj
# 63637  1qZyM5DozaVtdrRrW7imrR
# 63638  6BqNAwJyKkz59EQUwQFdw0
# 63639  3xyEIhMFhaVW3dhXu81iiU
# 63640  7xl50xr9NDkd3i2kBbzsNZ
# 63641  1qZyM5DozaVtdrRrW7imrR
# 63642  0H8Qz4f75jjsQaALOmbf8O
# 63643  71Z4V79RLI7DdKMAFoHfWG
# 63644  6kZOwjHj6PgaqEJfMWsU7v
# 63645  6QLRh3cxDFW1kzXlIh9H1U
# 63646  71Z4V79RLI7DdKMAFoHfWG
# 63647  7xl50xr9NDkd3i2kBbzsNZ
#
#                                             album.images  \
# 0      [{u'url': u'https://i.scdn.co/image/193fba2e87...
# 1      [{u'url': u'https://i.scdn.co/image/f8b5bed9f9...
# 2      [{u'url': u'https://i.scdn.co/image/bbf2d9892e...
# 3      [{u'url': u'https://i.scdn.co/image/181341d4f8...
# 4      [{u'url': u'https://i.scdn.co/image/14fab7c0b9...
# 5      [{u'url': u'https://i.scdn.co/image/855559b71a...
# 6      [{u'url': u'https://i.scdn.co/image/fd2df0c886...
# 7      [{u'url': u'https://i.scdn.co/image/66612a18d3...
# 8      [{u'url': u'https://i.scdn.co/image/b29addcd8a...
# 9      [{u'url': u'https://i.scdn.co/image/e533d2de41...
# 10     [{u'url': u'https://i.scdn.co/image/013177343b...
# 11     [{u'url': u'https://i.scdn.co/image/9680050a2c...
# 12     [{u'url': u'https://i.scdn.co/image/b2eca1bbf9...
# 13     [{u'url': u'https://i.scdn.co/image/b864953475...
# 14     [{u'url': u'https://i.scdn.co/image/19a3c22fec...
# 15     [{u'url': u'https://i.scdn.co/image/9cb5c89900...
# 16     [{u'url': u'https://i.scdn.co/image/9ef2950d87...
# 17     [{u'url': u'https://i.scdn.co/image/f6ac5b397e...
# 18     [{u'url': u'https://i.scdn.co/image/71a99085bc...
# 19     [{u'url': u'https://i.scdn.co/image/ef8872c93c...
# 20     [{u'url': u'https://i.scdn.co/image/89225fa98d...
# 21     [{u'url': u'https://i.scdn.co/image/75fc618857...
# 22     [{u'url': u'https://i.scdn.co/image/e0e177893c...
# 23     [{u'url': u'https://i.scdn.co/image/b85943feea...
# 24     [{u'url': u'https://i.scdn.co/image/c815fbf301...
# 25     [{u'url': u'https://i.scdn.co/image/c815fbf301...
# 26     [{u'url': u'https://i.scdn.co/image/e635524518...
# 27     [{u'url': u'https://i.scdn.co/image/fdacf5928c...
# 28     [{u'url': u'https://i.scdn.co/image/204ba55887...
# 29     [{u'url': u'https://i.scdn.co/image/9244a9af1a...
# ...                                                  ...
# 63618  [{u'url': u'https://i.scdn.co/image/fd62b1f4f6...
# 63619  [{u'url': u'https://i.scdn.co/image/e844ca0c71...
# 63620  [{u'url': u'https://i.scdn.co/image/1e67bbf4b4...
# 63621  [{u'url': u'https://i.scdn.co/image/93b0de939b...
# 63622  [{u'url': u'https://i.scdn.co/image/9a7f8e88be...
# 63623  [{u'url': u'https://i.scdn.co/image/fd62b1f4f6...
# 63624  [{u'url': u'https://i.scdn.co/image/fd62b1f4f6...
# 63625  [{u'url': u'https://i.scdn.co/image/a02cec0d9c...
# 63626  [{u'url': u'https://i.scdn.co/image/1ffdecc8b0...
# 63627  [{u'url': u'https://i.scdn.co/image/928d7cf5f0...
# 63628  [{u'url': u'https://i.scdn.co/image/9a7f8e88be...
# 63629  [{u'url': u'https://i.scdn.co/image/2bf8d2b179...
# 63630  [{u'url': u'https://i.scdn.co/image/6edb5fa126...
# 63631  [{u'url': u'https://i.scdn.co/image/05bca20d14...
# 63632  [{u'url': u'https://i.scdn.co/image/41dfa2e8b9...
# 63633  [{u'url': u'https://i.scdn.co/image/9a7f8e88be...
# 63634  [{u'url': u'https://i.scdn.co/image/751829ef85...
# 63635  [{u'url': u'https://i.scdn.co/image/613bf55fbf...
# 63636  [{u'url': u'https://i.scdn.co/image/bb62f17ffd...
# 63637  [{u'url': u'https://i.scdn.co/image/9a7f8e88be...
# 63638  [{u'url': u'https://i.scdn.co/image/2a4bedf9ee...
# 63639  [{u'url': u'https://i.scdn.co/image/10bedd67bb...
# 63640  [{u'url': u'https://i.scdn.co/image/fd62b1f4f6...
# 63641  [{u'url': u'https://i.scdn.co/image/9a7f8e88be...
# 63642  [{u'url': u'https://i.scdn.co/image/5db049a600...
# 63643  [{u'url': u'https://i.scdn.co/image/751829ef85...
# 63644  [{u'url': u'https://i.scdn.co/image/532ba7470d...
# 63645  [{u'url': u'https://i.scdn.co/image/82f5554402...
# 63646  [{u'url': u'https://i.scdn.co/image/751829ef85...
# 63647  [{u'url': u'https://i.scdn.co/image/fd62b1f4f6...
#
#                                            album.name album.release_date  \
# 0                                    Howl At the Moon         2014-02-03
# 1                                        Save Me (EP)         2014-04-16
# 2                                    Don't Go Lose It         2014-02-10
# 3                                     Apart (Remixes)         2014-03-31
# 4                           Left Behinds (Radio Edit)         2014-07-18
# 5                      Kuaga (Lost Time) (Radio Edit)         2015-05-16
# 6         Spinnin Sessions Amsterdam Dance Event 2014         2014-10-08
# 7                                        Abandon Ship         2014-11-04
# 8                        Soundwave (Audiotricz Remix)         2014-05-19
# 9                                            Kingwood         2014-12-22
# 10                    Random White Dude Be Everywhere         2014-07-29
# 11                   Nicky Romero presents Miami 2015         2015-03-16
# 12                             Move Showcase ADE 2015         2015-10-12
# 13                 Oorah! (Strong Viking Anthem 2015)         2015-04-10
# 14                                               Slap         2015-01-26
# 15                               How to Break a Heart         2014-12-30
# 16                                             S.A.X.         2015-01-05
# 17     Electric For Life 2015 (Mixed by Gareth Emery)         2015-12-04
# 18                                Rumors (Radio Edit)         2015-02-09
# 19                                Winner (Radio Edit)         2015-02-02
# 20                 Champions (feat. Harry Brooks Jnr)         2014-06-16
# 21                                 Remember to Forget         2014-02-28
# 22                    Love Progressive House - Vol. 2         2014-12-08
# 23         The Sound Of Revealed 2014 (Mixed Version)         2014-11-28
# 24            Nicky Romero presents Protocol ADE 2014         2014-10-27
# 25            Nicky Romero presents Protocol ADE 2014         2014-10-27
# 26                                            Skyline         2015-02-09
# 27                      No Way Out (feat. Kat Nestel)         2015-02-02
# 28                                        Getting Off         2015-09-28
# 29                                     Randale (Live)         2015-11-20
# ...                                               ...                ...
# 63618                                Stadium Arcadium         2006-05-09
# 63619                                  Nicky Jam Hits         2014-09-09
# 63620                     Join Me (feat. Anica Russo)         2017-05-12
# 63621                                        With You         2015-01-12
# 63622                    Convergence (Deluxe Edition)         2015-10-16
# 63623                                Stadium Arcadium         2006-05-09
# 63624                                Stadium Arcadium         2006-05-09
# 63625                                   Sun Goes Down         2017-10-12
# 63626                     The Very Best of Lucia Popp         2003-08-04
# 63627                                        Together         2017-01-20
# 63628                    Convergence (Deluxe Edition)         2015-10-16
# 63629                                       Landscape         2017-01-02
# 63630                                  Give Me Summer         2017-06-09
# 63631                                   Chunga Changa         2014-11-24
# 63632                                          Isteri         2014-01-10
# 63633                    Convergence (Deluxe Edition)         2015-10-16
# 63634                                     2 the World         2015-04-07
# 63635                               Freed From Desire         2009-06-18
# 63636                                          Leeloo         2016-12-12
# 63637                    Convergence (Deluxe Edition)         2015-10-16
# 63638                           Line (Stan Sax Remix)               2017
# 63639                       I Need You (feat. Francy)         2012-01-19
# 63640                                Stadium Arcadium         2006-05-09
# 63641                    Convergence (Deluxe Edition)         2015-10-16
# 63642                                  Ko Vam Je Reko         2017-06-16
# 63643                                     2 the World         2015-04-07
# 63644                                        Daydream         2017-03-15
# ...
# 63618  https://api.spotify.com/v1/audio-analysis/31EJ...         0.577
# 63619  https://api.spotify.com/v1/audio-analysis/25GR...         0.763
# 63620  https://api.spotify.com/v1/audio-analysis/4hGK...         0.709
# 63621  https://api.spotify.com/v1/audio-analysis/0VkO...         0.832
# 63622  https://api.spotify.com/v1/audio-analysis/5znE...         0.830
# 63623  https://api.spotify.com/v1/audio-analysis/0CZQ...         0.546
# 63624  https://api.spotify.com/v1/audio-analysis/6gTd...         0.374
# 63625  https://api.spotify.com/v1/audio-analysis/0u5c...         0.897
# 63626  https://api.spotify.com/v1/audio-analysis/2hOc...         0.349
# 63627  https://api.spotify.com/v1/audio-analysis/4h64...         0.742
# 63628  https://api.spotify.com/v1/audio-analysis/4maH...         0.755
# 63629  https://api.spotify.com/v1/audio-analysis/5L8V...         0.789
# 63630  https://api.spotify.com/v1/audio-analysis/5vcz...         0.743
# 63631  https://api.spotify.com/v1/audio-analysis/6PpS...         0.945
# 63632  https://api.spotify.com/v1/audio-analysis/5w2z...         0.673
# 63633  https://api.spotify.com/v1/audio-analysis/2pmH...         0.785
# 63634  https://api.spotify.com/v1/audio-analysis/7obN...         0.844
# 63635  https://api.spotify.com/v1/audio-analysis/3p4g...         0.601
# 63636  https://api.spotify.com/v1/audio-analysis/0HEE...         0.661
# 63637  https://api.spotify.com/v1/audio-analysis/7yhd...         0.540
# 63638  https://api.spotify.com/v1/audio-analysis/0LuN...         0.746
# 63639  https://api.spotify.com/v1/audio-analysis/6QJY...         0.787
# 63640  https://api.spotify.com/v1/audio-analysis/0itN...         0.695
# 63641  https://api.spotify.com/v1/audio-analysis/5e0Q...         0.849
# 63642  https://api.spotify.com/v1/audio-analysis/3d90...         0.814
# 63643  https://api.spotify.com/v1/audio-analysis/5XFz...         0.788
# 63644  https://api.spotify.com/v1/audio-analysis/2Uev...         0.745
# 63645  https://api.spotify.com/v1/audio-analysis/2uGW...         0.812
# 63646  https://api.spotify.com/v1/audio-analysis/5aYo...         0.920
# 63647  https://api.spotify.com/v1/audio-analysis/1jrA...         0.671
#
#        duration_ms.1  energy  instrumentalness  key  liveness  loudness  mode  \
# 0             539130   0.966          0.834000    9    0.0294    -7.146     0
# 1             351971   0.754          0.000210    4    0.0849    -5.879     0
# 2             324058   0.943          0.473000    5    0.1100    -4.029     0
# 3             311250   0.894          0.006960   10    0.1060    -5.985     1
# 4             180015   0.957          0.033100    8    0.1430    -4.051     0
# 5             177415   0.970          0.005300    1    0.2010    -3.994     1
# 6             296250   0.821          0.773000    2    0.2180    -4.976     0
# 7             251173   0.970          0.219000   10    0.0313    -2.909     0
# 8             199624   0.696          0.000000    4    0.0814    -4.671     1
# 9             277943   0.816          0.784000    7    0.1350    -6.051     1
# 10            281250   0.957          0.132000    6    0.0622    -3.486     1
# 11            352505   0.864          0.059000    9    0.3000    -5.252     1
# 12            411290   0.640          0.442000    7    0.0895    -7.890     1
# 13            281108   0.755          0.923000    9    0.2720    -6.521     0
# 14            264834   0.981          0.774000    6    0.1430    -2.588     0
# 15            241832   0.743          0.000148    0    0.3140    -4.989     0
# 16            182960   0.994          0.844000    1    0.1300    -3.469     1
# 17            215320   0.799          0.000004    5    0.3670    -7.075     0
# 18            171545   0.807          0.009070    5    0.2200    -4.478     0
# 19            172500   0.909          0.195000    3    0.0909    -3.980     0
# 20            209062   0.791          0.000000    6    0.0863    -3.799     0
# 21            307025   0.795          0.000009    5    0.0555    -3.705     0
# 22            348755   0.950          0.399000    5    0.0834    -4.028     0
# 23            240000   0.991          0.901000    5    0.1110    -2.980     1
# 24            337964   0.782          0.852000    0    0.1410    -6.737     0
# 25            355781   0.978          0.001560    6    0.3210    -2.943     0
# 26            307266   0.995          0.876000    2    0.8810    -3.591     1
# 27            206814   0.864          0.000000    0    0.2410    -4.287     0
# 28            359649   0.971          0.028800    7    0.0786    -4.724     1
# 29            324240   0.968          0.000007    9    0.9340    -4.867     1
# ...              ...     ...               ...  ...       ...       ...   ...
# 63618         245893   0.766          0.000037    1    0.1580    -3.786     0
# 63619         211888   0.760          0.000000    0    0.1330    -4.672     1
# 63620         190161   0.731          0.000000    8    0.1930    -5.768     0
# 63621         332000   0.639          0.000208    5    0.5980    -5.995     0
# 63622         190000   0.677          0.000005    6    0.0438    -6.012     0
# 63623         228667   0.884          0.000276   11    0.4570    -3.719     0
# 63624         224440   0.988          0.000002    4    0.1730    -1.911     1
# 63625         186707   0.658          0.008040    9    0.0882    -7.013     1
# 63626         249960   0.142          0.000000    7    0.1220   -16.097     1
# 63627         208525   0.849          0.887000    7    0.0962    -5.057     0
# 63628         266747   0.643          0.834000    2    0.1130    -7.651     0
# 63629         293561   0.826          0.890000    1    0.6580    -4.543     1
# 63630         204595   0.701          0.506000    2    0.0852    -9.180     0
# 63631         314756   0.823          0.458000    5    0.0503    -5.513     0
# 63632         240000   0.434          0.455000    7    0.3510    -9.579     0
# 63633         223667   0.547          0.028200    6    0.0894   -10.589     0
# 63634         227811   0.586          0.000000    0    0.2580    -5.840     0
# 63635         233064   0.906          0.000001    0    0.2190    -7.716     1
# 63636         307522   0.561          0.812000    9    0.1370   -11.522     0
# 63637         238720   0.834          0.002820    0    0.1580    -6.942     1
# 63638         252566   0.693          0.016400    6    0.0894    -5.182     0
# 63639         295969   0.690          0.765000    1    0.0763    -5.227     1
# 63640         247667   0.993          0.002170    0    0.0877    -3.102     1
# 63641         299427   0.611          0.001940    9    0.0351    -7.704     0
# 63642         166616   0.728          0.000000    2    0.0719    -5.593     1
# 63643         170086   0.304          0.000000    4    0.1070    -9.326     1
# 63644         182913   0.743          0.038800    5    0.1550    -7.803     1
# 63645         329538   0.648          0.311000   10    0.0829    -7.916     0
# 63646         179328   0.827          0.000000    7    0.0547    -6.012     0
# 63647         205733   0.984          0.000000    7    0.1130    -2.381     1
#
#        speechiness    tempo  time_signature  \
# 0           0.0566  137.999               4
# 1           0.0702  127.985               4
# 2           0.0463  128.003               4
# 3           0.0388  128.024               4
# 4           0.1520  128.027               4
# 5           0.1250  127.953               4
# 6           0.0382  128.019               4
# 7           0.0641  174.009               4
# 8           0.0418  148.172               4
# 9           0.1680  127.998               4
# 10          0.0898  127.948               4
# 11          0.0636  127.998               4
# 12          0.1560  121.985               4
# 13          0.0637  192.114               3
# 14          0.0540  127.994               4
# 15          0.0534  128.084               4
# 16          0.0780  127.975               4
# 17          0.0704  129.341               4
# 18          0.0465  124.948               4
# 19          0.0548  128.022               4
# 20          0.0656  127.990               4
# 21          0.1160  129.955               4
# 22          0.3560  127.992               4
# 23          0.0556  127.995               4
# 24          0.0776  128.011               4
# 25          0.0728  127.982               4
# 26          0.0643  128.006               4
# 27          0.0527  126.021               4
# 28          0.0848  150.018               4
# 29          0.2230  158.914               4
# ...            ...      ...             ...
# 63618       0.0267   88.013               4
# 63619       0.0596  163.969               4
# 63620       0.0300  123.957               4
# 63621       0.0733  120.020               4
# 63622       0.0945  120.004               4
# 63623       0.0374  112.331               4
# 63624       0.1690  149.146               4
# 63625       0.1720  128.008               4
# 63626       0.0518  139.158               5
# 63627       0.0502  121.982               4
# 63628       0.0546  118.006               4
# 63629       0.0582  126.021               4
# 63630       0.0434  121.926               4
# 63631       0.0832  123.017               4
# 63632       0.0353   95.042               4
# 63633       0.0489  119.944               4
# 63634       0.0566  140.059               4
# 63635       0.1220  129.124               4
# 63636       0.0653  127.975               4
# 63637       0.0531  117.086               4
# 63638       0.0619  114.930               4
# 63639       0.0472  128.015               4
# 63640       0.0614  107.933               4
# 63641       0.0571  115.036               4
# 63642       0.2330  115.057               4
# 63643       0.0665  120.082               4
# 63644       0.0616  102.983               4
# 63645       0.0405  120.006               4
# 63646       0.0886  133.973               4
# 63647       0.0955   97.743               4
#
#                                               track_href          type.1  \
# 0      https://api.spotify.com/v1/tracks/5Vlxqtw5xC2t...  audio_features
# 1      https://api.spotify.com/v1/tracks/1vScEbMXJslS...  audio_features
# 2      https://api.spotify.com/v1/tracks/0RMtbz2AKZXM...  audio_features
# 3      https://api.spotify.com/v1/tracks/4LzfByj2wTGZ...  audio_features
# 4      https://api.spotify.com/v1/tracks/3QquT92Ti517...  audio_features
# 5      https://api.spotify.com/v1/tracks/2ce5n5MpJQgv...  audio_features
# 6      https://api.spotify.com/v1/tracks/43k8fgVQhZYZ...  audio_features
# 7      https://api.spotify.com/v1/tracks/5v26uKaXYsWR...  audio_features
# 8      https://api.spotify.com/v1/tracks/7iWWmsgELL98...  audio_features
# 9      https://api.spotify.com/v1/tracks/70injMLRxsQg...  audio_features
# 10     https://api.spotify.com/v1/tracks/0GATmBanwPiH...  audio_features
# 11     https://api.spotify.com/v1/tracks/4oevcaqqQpR8...  audio_features
# 12     https://api.spotify.com/v1/tracks/0AQ4a4Evmy00...  audio_features
# 13     https://api.spotify.com/v1/tracks/1QEbrQlmtYVc...  audio_features
# 14     https://api.spotify.com/v1/tracks/1NgaWRYfMtTl...  audio_features
# 15     https://api.spotify.com/v1/tracks/63JD6EIQPwXM...  audio_features
# 16     https://api.spotify.com/v1/tracks/654YntfsU6il...  audio_features
# 17     https://api.spotify.com/v1/tracks/5jEipVlHWNIC...  audio_features
# 18     https://api.spotify.com/v1/tracks/7tu6IpmSey65...  audio_features
# 19     https://api.spotify.com/v1/tracks/26HMjtnUHasP...  audio_features
# 20     https://api.spotify.com/v1/tracks/0UFtsK5aSrq5...  audio_features
# 21     https://api.spotify.com/v1/tracks/54xvAdU6A4HZ...  audio_features
# 22     https://api.spotify.com/v1/tracks/79iGIEA5Ppbk...  audio_features
# 23     https://api.spotify.com/v1/tracks/1Bu1nVp4rWu7...  audio_features
# 24     https://api.spotify.com/v1/tracks/1Wyo20oMjhSY...  audio_features
# 25     https://api.spotify.com/v1/tracks/67j4DNda2VS8...  audio_features
# 26     https://api.spotify.com/v1/tracks/7LwNbU51jSEN...  audio_features
# 27     https://api.spotify.com/v1/tracks/0LI4BP3JHQw0...  audio_features
# 28     https://api.spotify.com/v1/tracks/0jJ7AZj9ZDPT...  audio_features
# 29     https://api.spotify.com/v1/tracks/2qRVadW0yxjN...  audio_features
# ...                                                  ...             ...
# 63618  https://api.spotify.com/v1/tracks/31EJcKUZGaDC...  audio_features
# 63619  https://api.spotify.com/v1/tracks/25GRgMoXezpp...  audio_features
# 63620  https://api.spotify.com/v1/tracks/4hGKMuDQCgWx...  audio_features
# 63621  https://api.spotify.com/v1/tracks/0VkOpoN1xFZP...  audio_features
# 63622  https://api.spotify.com/v1/tracks/5znEiVKJITQ1...  audio_features
# 63623  https://api.spotify.com/v1/tracks/0CZQNI3Evb4N...  audio_features
# 63624  https://api.spotify.com/v1/tracks/6gTdrud3duWI...  audio_features
# 63625  https://api.spotify.com/v1/tracks/0u5coU84PCSN...  audio_features
# 63626  https://api.spotify.com/v1/tracks/2hOc4ZFuRUFc...  audio_features
# 63627  https://api.spotify.com/v1/tracks/4h64A3xWnYzP...  audio_features
# 63628  https://api.spotify.com/v1/tracks/4maH3qPU16vg...  audio_features
# 63629  https://api.spotify.com/v1/tracks/5L8V6TPunEUj...  audio_features
# 63630  https://api.spotify.com/v1/tracks/5vczxprsg5zJ...  audio_features
# 63631  https://api.spotify.com/v1/tracks/6PpSq6Eb9wE0...  audio_features
# 63632  https://api.spotify.com/v1/tracks/5w2zI2TnxiP4...  audio_features
# 63633  https://api.spotify.com/v1/tracks/2pmHkc7h9gPj...  audio_features
# 63634  https://api.spotify.com/v1/tracks/7obN7CIn2WQq...  audio_features
# 63635  https://api.spotify.com/v1/tracks/3p4gKJtHQN3c...  audio_features
# 63636  https://api.spotify.com/v1/tracks/0HEEAuKXY3wO...  audio_features
# 63637  https://api.spotify.com/v1/tracks/7yhdrrz7dvsq...  audio_features
# 63638  https://api.spotify.com/v1/tracks/0LuNSgpNYWPo...  audio_features
# 63639  https://api.spotify.com/v1/tracks/6QJYxTKD0rMG...  audio_features
# 63640  https://api.spotify.com/v1/tracks/0itNMuBHye9f...  audio_features
# 63641  https://api.spotify.com/v1/tracks/5e0Q4X1HKFBF...  audio_features
# 63642  https://api.spotify.com/v1/tracks/3d90L14szDmA...  audio_features
# 63643  https://api.spotify.com/v1/tracks/5XFzqvGBZBy7...  audio_features
# 63644  https://api.spotify.com/v1/tracks/2UevXnfjokON...  audio_features
# 63645  https://api.spotify.com/v1/tracks/2uGWFmJYpJMU...  audio_features
# 63646  https://api.spotify.com/v1/tracks/5aYozSl90qcF...  audio_features
# 63647  https://api.spotify.com/v1/tracks/1jrARDhheF2n...  audio_features
#
#        valence
# 0        0.335
# 1        0.527
# 2        0.717
# 3        0.167
# 4        0.155
# 5        0.364
# 6        0.235
# 7        0.648
# 8        0.337
# 9        0.117
# 10       0.263
# 11       0.114
# 12       0.477
# 13       0.100
# 14       0.265
# 15       0.296
# 16       0.475
# 17       0.441
# 18       0.412
# 19       0.377
# 20       0.130
# 21       0.846
# 22       0.440
# 23       0.169
# 24       0.157
# 25       0.278
# 26       0.410
# 27       0.425
# 28       0.134
# 29       0.228
# ...        ...
# 63618    0.452
# 63619    0.916
# 63620    0.452
# 63621    0.291
# 63622    0.615
# 63623    0.620
# 63624    0.405
# 63625    0.320
# 63626    0.134
# 63627    0.126
# 63628    0.561
# 63629    0.326
# 63630    0.198
# 63631    0.810
# 63632    0.771
# 63633    0.539
# 63634    0.666
# 63635    0.583
# 63636    0.116
# 63637    0.377
# 63638    0.224
# 63639    0.178
# 63640    0.280
# 63641    0.357
# 63642    0.760
# 63643    0.378
# 63644    0.314
# 63645    0.707
# 63646    0.888
# 63647    0.871
#
# [63648 rows x 50 columns]

# %%
with open('lyrics.txt-61') as json_file:  
    data = json.load(json_file)
    print(data[0])
# Out:
# {'lyrics:3QquT92Ti51799zeBywMOj': "\n\n[Verse: Taylr Renee]\nCast me out, drug me through hell\nDevil's ashes live under my nails\nWhere's the hope, belief in humanity?\nAsk for a drink, strangers look down on me\n\n[Chorus: Taylr Renee]\nFallen angel, that is I\nI'll lead you all you left behinds\nNow is ever do or die\nTogether, no man left behind\nWe are the left behinds\n\n[Instrumental Drop: Paris Blohm]\nWe are\nThe left behinds\n\n[Verse 2: Taylr Renee]\nMetal hearts melted down\nPool of souls I wish to drown\nWhere's the hope, belief in humanity?\nAsk for a drink, strangers look down on me\n\n[Chorus: Taylr Renee]\nFallen angel, that is I\nI'll lead you all you left behinds\nNow is ever do or die\nTogether, no man left behind\nWe are the left behinds\n\n[Instrumental Drop: Paris Blohm]\nWe are the left behinds\n\n", 'lyrics:2ce5n5MpJQgvnAHtmfxS1C': "\n\n[Verse 1]\nEyes flicker, heart beats quicker inside\nLet's start making up for lost time\nBacks to the wind, we can do this all night\nSinging hey, let's get away, we'll make it alright\n\n[Chorus]\nIt's been a while, been a really long time\nI like you better now\nI wish you'd stay a while\nBefore we begin to say goodbye\nLet's start making up for lost time\n\n[Drop]\nFor lost time (lost time)\nFor lost time (lost time)\nFor lost time (lost time)\nLet's start making up for lost time\n\n[Verse 2]\nSo here, take my hand, we can kick it up again\nWe're never coming back, now we found our place in the skyline\nSo let's start making up for lost time\n\n[Chorus]\nIt's been a while, been a really long time\nI like you better now\nI wish you'd stay a while\nBefore we begin to say goodbye\nLet's start making up for lost time (lost time)\nFor lost time (lost time)\nLet's start making up for lost time (lost time)\n\n[Drop]\nFor lost time (lost time)\nFor lost time (lost time)\nFor lost time (lost time)\nLet's start making up for lost time\n\n", 'lyrics:0RMtbz2AKZXMAL4cP0tXRm': '\n\n[Instrumental Intro]\n\n[Verse 1]\nEverybody out there in Soweto\nDon’t go lose it, baby\nEverybody out there in Soweto\nDon’t go lose it, baby\n\n[Pre-Break]\nDon’t go\nDon’t go lose it, baby\nDon’t go\nDon’t go lose it, baby\n\n[Instrumental Break]\n\n[Verse 2]\nA winner never ever\nNever ever, stays behind\nA winner comes a quick run far\nA winner don’t give up\nA winner breaks the record\nA winner is ready for talk\nYes a winner is on the move\nA winner is the mood\n\n[Pre-Break]\nDon’t go\nDon’t go lose it, baby\nDon’t go\nDon’t go lose it, baby\nDon’t go\n\n[Instrumental Break]\n\n[Instrumental Outro]\n\n'}

# %%
#songResults.to_csv('newresults.csv', index=False)

#songResults.iloc[0, 0] = 'spotify:track:5JiLJJbuA92jnPoQJ7WhkK'
song.iloc[0,12]

# %%
#Create an instance of the trackInfo class
trackInfo = TrackInfo("spotify:track:1vScEbMXJslS5xx5noo0Ch")
print(trackInfo.artist)    

#trackTitle = trackInfo.processTrackName(trackInfo.title, trackInfo.album)
        
        #Make a call to Genius and retrive matches of title-artist combination in the genius lyrics database
#print(trackTitle)
#print(trackInfo.artist)
#geniusResponse = trackInfo.fetch_lyrics_page(trackTitle, trackInfo.artist)    
#print(geniusResponse)
        #Genius call returns the best possible matches. Find the title-artist that best matched spotify input title-artist
#matchedTrack = trackInfo.findResponseMatch(geniusResponse, trackInfo.artist, trackInfo.title, trackInfo.album)
trackInfo.getArtistCountry("German", 'https://genius.com/artists/Pierce-fulton')

# %%
s = 'Vermont, USA,'
s[0:-2]

# %%
print(fuzz.partial_ratio('savemejakkoremix', 'essaysofmicheldemontaignechap212'))
print(fuzz.token_set_ratio('savemejakkoremix', 'essaysofmicheldemontaignechap212'))

# %%
print(ents)

from google import google
num_page = 3
search_results = google.search("Nationality of Michael Jackson", 1)
for result in search_results:
    print(result.description)
    
    import lyricsgenius
genius = lyricsgenius.Genius("YkmxZvf4kNPOxSd3aTuuczGjWDZintTlgGLQYtjxAy4__gQbpl-EENB_LRb1Nwaz")
song = genius.search_song(d['title'], d['artist'])
print(song)

import spotipy.util as util

USERNAME = "gk"
CLIENT_ID = "314c62651741485eb3bdc9c07f8d5b73"
CLIENT_SECRET = "e6d17930c5df497ba2fa1f1bfce6321b"
REDIRECT_URI = "https://example.com/callback/"
SCOPE = "user-read-recently-played user-top-read user-library-read playlist-read-private user-read-currently-playing user-follow-read"

token = util.prompt_for_user_token(username = USERNAME, 
                                   scope = SCOPE, 
                                   client_id = CLIENT_ID, 
                                   client_secret = CLIENT_SECRET, 
                                   redirect_uri = REDIRECT_URI)

if token:
   sp = spotipy.Spotify(auth=token)
   song = sp.current_user_playing_track()
   print(song)

analysis = sp.audio_analysis('5bH79DlrqPshiR1CnwhBp0')
print(analysis)

# %%
fuzz.partial_ratio('orjannilsenjonathanmendelsohn', 'ørjannilsen')

# %%
fuzz.token_set_ratio('orjannilsenjonathanmendelsohn', 'ørjannilsen')

# %%
def rate_limit():

# %%
#song = pd.read_csv('results_id_queries.csv')
song.iloc[0,:]

# %%
client_id = "314c62651741485eb3bdc9c07f8d5b73"
client_secret = "e6d17930c5df497ba2fa1f1bfce6321b"
redirect_url = "https://localhost:8888/callback"

#Spotify api call
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
a = sp.track('spotify:track:30WFsBOtLhRWkNRGw6P82m')

# %%
flat = flatdict.FlatDict(a, delimiter='.')
print(flat)

# %%
dict1 = {'bookA': 1, 'bookB': 2, 'bookC': 3}
dict2 = {'bookC': 2, 'bookD': 4, 'bookE': 5}
dict2.update(dict1)

print(dict2)

# %%
print(get_current_track_info())
#print(sp.track('spotify:track:5Vlxqtw5xC2tzCkuR3sadb'))
# Out:
# {'album': dbus.String('Howl At the Moon', variant_level=1), 'artist': dbus.String('Driftmoon'), 'trackId': dbus.String('spotify:track:5Vlxqtw5xC2tzCkuR3sadb', variant_level=1), 'title': dbus.String('Howl At the Moon - Original Mix', variant_level=1)}

# %%
a = songResults[(pd.notnull(songResults['music.title'])) & ((songResults['music.artist'] != '<unknown>') & (songResults['music.artist'] != '<Unbekannt>') & (pd.notnull(songResults['music.artist'])))]

print(np.where(pd.isnull(songResults['uri'])))
print()

#Convert the dictionary to a dataframe
        df = pd.DataFrame(songsInfo, index=[0])
        df.to_csv('songs.csv')

        re.sub(r'[\W_]+', u'', s.lower(), flags=re.UNICODE)
print(s.translate(s.maketrans('', '', '[\W_]+')))

if 'hardwork' in 'workhard':
    print('l')
