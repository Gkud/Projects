# %%
import re
import dbus
import json
import spacy
import langid
import string
import spotipy
import requests
import flatdict
import itertools
import numpy as np
import pandas as pd
from time import time
import en_core_web_sm
from time import sleep
from random import randint
from fuzzywuzzy import fuzz
from bs4 import BeautifulSoup
from fuzzywuzzy import process
from collections import OrderedDict
from IPython.core.display import clear_output
from spotipy.oauth2 import SpotifyClientCredentials

# %%
class TrackInfo:
    '''A class containing methods to retrieve metada and lyrics of Spotify tracks'''
    
    def __init__(self):        
        ''' Instantiate spotify session
            Return: track object with its title, artist and album'''
        
        #Dictionary with ISO-language codes mapped to languages
        self.codes = {"af":"Afrikaans", "am":"Amharic", "an":"Aragonese", "ar":"Arabic", "as":"Assamese", "az":"Azerbaijani",\
                "be":"Belarusian", "bg":"Bulgarian", "bn":"Bengali", "br":"Breton", "bs":"Bosnian",\
                "ca":"Catalan", "cs":"Czech", "cy":"Welsh", "da":"Danish", "de":"German", "dz":"Dzongkha",\
                "el":"Greek", "en":"English", "eo":"Esperanto", "es":"Spanish", "et":"Estonian", "eu":"Basque",\
                "fa":"Persian", "fi":"Finnish", "fo":"Faroese", "fr":"French", "ga":"Irish", "gl":"Galician", "gu":"Gujarati", \
                "he":"Hebrew", "hi":"Hindi", "hr":"Croatian", "ht":"Haitian", "hu":"Hungarian", "hy":"Armenian",\
                "id":"Indonesian", "is":"Icelandic", "it":"Italian", "ja":"Japanese", "jv":"Javanese", \
                "ka":"Georgian", "kk":"Kazakh", "km":"Central Khmer", "kn":"Kannada", "ko":"Korean", "ku":"Kurdish", "ky":"Kirghiz",\
                "la":"Latin", "lb":"Luxembourgish", "lo":"Lao", "lt":"Lithuanian", "lv":"Latvian", "mg":"Malagasy", "mk":"Macedonian", \
                "ml":"Malayalam", "mn":"Mongolian", "mr":"Marathi", "ms":"Malay", "mt":"Maltese", "nb":"Norwegian Bokmål", "ne":"Nepali",\
                "nl":"", "nn":"Norwegian Nynorsk", "no":"Norwegian", "oc":"Occitan", "or":"Oriya", "pa":"Punjabi", "pl":"Polish",\
                "ps":"Pashto", "pt":"Portuguese", "qu":"Quechua", "ro":"Romanian", "ru":"Russian", "rw":"Kinyarwanda",\
                "se":"Northern Sami", "si":"Sinhala", "sk":"Slovak", "sl":"Slovenian", "sq":"Albanian", "sr":"Serbian", \
                "sv":"Swedish", "sw":"Swahili", "ta":"Tamil", "te":"Telugu", "th":"Thai", "tl":"Tagalog", "tr":"Turkish",\
                "ug":"Uighur", "uk":"Ukrainian", "ur":"Urdu", "vi":"Vietnamese", "vo":"Volapük", \
                "wa":"Walloon", "xh":"Xhosa", "zh":"Chinese", "zu":"Zulu"}
        
        self.spotify = None
        self.trackDict = dict()

        # API tokens
        client_id = "314c62651741485eb3bdc9c07f8d5b73"
        client_secret = "e6d17930c5df497ba2fa1f1bfce6321b"
        redirect_url = "https://localhost:8888/callback"

        #Spotify api call
        try:
            client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
            self.spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
        except:
            print("Exception during Spotify session initialization")
        
    
    def unpack(self, result):
        # Retrieve the track title, album name and artist names from spotify track metadata
        # If there are multiple artist append with '&'
        self.req = 0
        if result:
            # Flatten the nested metadata dictionary. Nested keys are joined with '.' delimeter
            self.trackDict = flatdict.FlatDict(result, delimiter='.')
            self.track_id = self.trackDict['uri']
            self.title = self.trackDict['name']
            self.artist = ' & '.join([i['name'] for i in self.trackDict['artists']])
            self.album = self.trackDict['album.name']
            self.album_uri = self.trackDict['album.uri']
            self.artist_uri = [i['uri'] for i in self.trackDict['artists']]
    
    def processTrackName(self, title, album):
        '''Returns the processed name of the track by removing appended details like album
           This makes it possible to fetch the lyrics from Genius API by passing the track title
           as the API returns a null result if the track title is passed along with other appended details
        '''
        title = re.sub(r'[\(\[\{].*?[\)\]\}]', "", title)
        title = (title.split('-')[0]).strip()
        if album:
            ratio1 = fuzz.partial_ratio(album, title)
            ratio2 = fuzz.token_set_ratio(album, title)
            if ratio1 < 45 and ratio2 < 45:
                title = title.replace(album, '')
        return title.strip()
        
    def fetch_lyrics_page(self, song_title, artist_name):
        '''Make a request to Genius API to search and fetch the lyrics page of the track'''
        response = None
        base_url = 'https://api.genius.com'
        headers = {'Authorization': 'Bearer YkmxZvf4kNPOxSd3aTuuczGjWDZintTlgGLQYtjxAy4__gQbpl-EENB_LRb1Nwaz'}
        search_url = base_url + '/search'
        data = {'q': song_title + ' ' + artist_name}
        try:
            response = requests.get(search_url, data=data, headers=headers)
            self.req = self.req + 1
            geniusResponse = response.json()
            i = 0
            names = artist_name.split('&')
            while (not geniusResponse['response']['hits']) and (i < len(names)):   
                data = {'q': song_title + ' ' + names[i]}
                response = requests.get(search_url, data=data, headers=headers)
                self.req = self.req + 1
                geniusResponse = response.json()
                i = i + 1
                sleep(randint(1,3))
            return geniusResponse
        except:
            print("Exception during request call to Genius")
    
        
    def processStrings(self, strng):
        '''Returns a processed string after removing punctutaion and converting to lowercase'''
        strng = re.sub(r'[\W_]+', u'', strng, flags=re.UNICODE)
        return strng.lower()
    
    def findResponseMatch(self, geniusResponse, artist_names, trackTitle, albumName):
        '''Find a match of the song in Genius database to fetch the track lyrics
           Steps: 1) Find a match for the artist_name
                  2) If the artist_name matches, check if the track title matches
                  
            Algorithm to match Artist Name
            1) Search for a match with the exact name as present in music.artist column in dataset(inputString)
            2) If a match is not found,
               a) Remove punctutation from the name string along with whitespace
               b) Convert the string to lowercase
               c) Apply steps 'a' and 'b' to the string "match['result']['primary_artist']['name']" from response object (responseString)
               d) Apply approximate string matching (use fuzzywuzzy package)
            
            Algorithm to match Track Title
            1) Search for a match with the exact name as present in music.title column in dataset(inputTitle)
            2) 
            
            Returns: response object entry for which matches on the artist and track title names
        '''
        
        track_info = None
        bestMatch = None
        bestRatio = {'Ratio':0, 'Result': None}
        inputArtist = self.processStrings(artist_names)
        inputTitle = self.processStrings(trackTitle)
        
        if geniusResponse and geniusResponse['response'] and geniusResponse['response']['hits']: 
            #Iterate through the response object
            for match in geniusResponse['response']['hits']:
                result = None
                responseArtist = self.processStrings(match['result']['primary_artist']['name'])
                # Search a match with the exact name in music.artist dataset column
                if responseArtist:                
                    if (responseArtist in inputArtist) or (inputArtist in responseArtist):
                        result = match['result']
                    else:
                        ratio1 = fuzz.partial_ratio(inputArtist, responseArtist)
                        ratio2 = fuzz.token_set_ratio(inputArtist, responseArtist)
                        if ratio1 > 70 and ratio2 > 70:
                            result = match['result']

                # If a match for the artist_name is found, find a match for the title track
                if result:
                    rtitle = self.processStrings(result['title'])
                    titleFeat = self.processStrings(result['title_with_featured'])
                    fullTitle = self.processStrings(result['full_title'])
                    # Search a match with the exact name in music.title dataset column
                    if (inputTitle == rtitle) or (inputTitle == titleFeat) or (inputTitle == fullTitle):
                        track_info = result
                        break
                    # Remove punctuations and convert to lower case
                    # Remove album name and artist names from the input string                
                    else:
                        processedTitle = self.processStrings(trackTitle.split('-')[0])
                        if (processedTitle == rtitle) or (processedTitle == titleFeat) or (processedTitle == fullTitle):
                            bestMatch = result
                        else:
                            processedTitle = self.processTrackName(processedTitle, albumName)
                            if (processedTitle == rtitle) or (processedTitle == titleFeat) or (processedTitle == fullTitle):
                                bestMatch = result
                            else:
                                ratio1 = fuzz.partial_ratio(inputTitle, rtitle)
                                ratio2 = fuzz.token_set_ratio(inputTitle, rtitle)
                                if ratio1 > 70 and ratio2 > 70 and (ratio1+ratio2) > bestRatio['Ratio']:
                                    bestRatio['Result'] = result                   
                else:
                    continue
                
        if (not track_info) and (bestMatch):
            track_info = bestMatch
        elif bestRatio['Result']:
            track_info = bestRatio['Result'] 

        return track_info

    def scrape_lyrics_artist_title(self, genius_track_url):
        '''Get lyrics of the track
           Returns: song lyrics, track title (as found in Genius), artist name (as found in Genius)
        '''        
        lyrics = None
        foundArtistName = None
        foundTrackTitle = None    
        featuredArtistName = None
        producerName = None
        other_track_info = {}
        page = requests.get(genius_track_url)
        self.req = self.req + 1
        html = BeautifulSoup(page.text, 'html.parser')
        lyricsClass = html.find('div', class_='lyrics')
        if lyricsClass:
            lyrics = lyricsClass.get_text()
        if html.find('div', class_='header_with_cover_art-primary_info'):
            titleTag = html.find('h1', class_ = 'header_with_cover_art-primary_info-title')
            artistTag = html.find('a', class_ = 'header_with_cover_art-primary_info-primary_artist')
            otherTag = html.find_all('h3')
            for i in range(len(otherTag)):
                key = otherTag[i].find('span', {'class': 'metadata_unit-label'})
                value = otherTag[i].find('span', {'class': 'metadata_unit-info'})
                if key:
                    other_track_info[key.get_text()] = value.get_text()

            if titleTag:
                foundTrackTitle = titleTag.get_text()
            if artistTag:
                foundArtistName = artistTag.get_text()

        return (lyrics, foundTrackTitle, foundArtistName, other_track_info)

    def scrape_artist_bio(self, genius_artist_url):
        '''Get artist description through Genius API'''
        artist_bio = None
        page = requests.get(genius_artist_url)
        self.req = self.req + 1
        html = BeautifulSoup(page.text, 'html.parser')
        infoTag = html.find('div', class_='rich_text_formatting')
        if infoTag:
            artist_bio = infoTag.get_text()
        return artist_bio
    
    def getTrackLanguage(self, lyrics):
        '''Returns the language of the track'''

        language = langid.classify(lyrics)
        return self.codes[language[0]]

    def getAudioFeatures(self):
        '''Returns Audio Features for a track'''
        self.req = self.req + 1
        return self.sp.audio_features(self.track_id)
    
    def getArtistGenre(self):
        '''Returns the Genre of the Artist'''
        genres = [(self.sp.artist(uri))['genres'] for uri in self.artist_uri]
        self.req = self.req + 1
        return list(itertools.chain.from_iterable(genres))
        
    def getAlbumGenre(self):
        '''Returns the Genre of the Album'''
        album = self.sp.albums([self.album_uri])
        self.req = self.req + 1
        return album['albums'][0]['genres']   
    
    def processArtistName(self, artist):
        '''Returns the exact name of the track by removing appended details
           This makes it possible to fetch the lyrics from Genius API by passing the track title
           as the API returns a null result if the track title is passed along with other appended details
        '''
        title = re.sub(r'\(.*?\)', "", title)
        title = title.split('-')[0]
        return title.strip()
    
    def getArtistCountry(self, songlang, artist_url):
        '''Return the country of the artist
           If the song language is not in English, then set language country as the country of the artist
           Else use the first four sentences of the artist bio to detect the country
           Since the information about the nationality is present in the first four-five lines of the biography      
        '''
        country = ''
        if songlang != "English":
            country = songlang
        else:
        #Use the artist url to scrape the Artist biography from Genius
            if artist_url:
                artist_info = self.scrape_artist_bio(artist_url)

                if artist_info:
                    infoLang = langid.classify(artist_info)
                    if infoLang[0] != 'en':
                        country = self.codes[infoLang[0]]
                    else:
                        splitText = artist_info.split('.')
                        length = len(splitText)
                        shortText = None
                        if length >= 1:
                            shortText = splitText[0]
                        if length > 2:
                            shortText = shortText + ". " +  splitText[1]
                        if length > 3:
                            shortText = shortText + ". " +  splitText[2]

                        if shortText:
                            nlp = en_core_web_sm.load()
                            doc = nlp(shortText)
                            st = ''
                            for ent in doc.ents:
                                if ent.label_ == "NORP":
                                    return ent.text
                                elif ent.label_ == "GPE":
                                    st = st + ent.text + ', '
                            country = st[0:-2]

        return country

# %%
def main():
    
    lyrics = []    
    tracks = []    
    trackLyrics = dict()    

    #Import the songs data into a dataframe
    songResults = pd.read_csv('results_id_queries.csv')
    song = pd.read_csv('songFinal.csv')
    w = song[:]
    w.drop_duplicates('uri', inplace=True)
    w.reset_index(inplace=True)
    l = np.unique(w['uri']).tolist()
    q = songResults[:]
    q.drop_duplicates('uri', inplace=True)
    newsn = q[~q.uri.isin(l)]
    
    k=0
    j = 0
    while j+18 <= 36:
        print('j:j+18', str(j) + ':' + str(j+18))
        sn = newsn[j:j+18+k]    
    
        uri_list = sn['uri'].tolist()        

        trackInfo = TrackInfo()

        tracksDetails = trackInfo.spotify.tracks(uri_list)
        artists_uris = [m['artists'][0]['uri'] for m in tracksDetails['tracks']]
        artists_genres = trackInfo.spotify.artists(artists_uris)
        album_genres = []
        audio_features = trackInfo.spotify.audio_features(uri_list)

        #Iterate over the rows of the dataframe
        for i in range(sn.shape[0]):
            print(i)
            value = sn.iloc[i, :]
            featuresDict = OrderedDict()
            track_info = None
            song_url = None
            artist_url = None
            track_lyrics = None
            artist_info = None
            songlang = None
            lyrics_state = None
            start_time = time()

            #Create an instance of the trackInfo class
            trackInfo.unpack(tracksDetails['tracks'][i])

            trackid = trackInfo.track_id.split(":")[-1]

            # Add values from dataframe to the dictionary
            featuresDict['track_uri'] = trackInfo.track_id
            featuresDict['music_title'] = value['music.title']
            featuresDict['music_artist'] = value['music.artist']
            featuresDict['music_album'] = value['music.album']
            featuresDict['found_title_spotify'] = trackInfo.title
            featuresDict['found_album_spotify'] = trackInfo.album
            featuresDict['found_artist_spotify'] = trackInfo.artist

            #Get the cleaned track title by removing appended details in brackets and albumName.
            #Split the string on  '-' and pass the first token in the call which is the actual title
            trackTitle = trackInfo.processTrackName(trackInfo.title, trackInfo.album)

            #Make a call to Genius and retrive matches of title-artist combination in the genius lyrics database
            geniusResponse = trackInfo.fetch_lyrics_page(trackTitle, trackInfo.artist)    

            #Genius call returns the best possible matches. Find the title-artist that best matched spotify input title-artist
            matchedTrack = trackInfo.findResponseMatch(geniusResponse, trackInfo.artist, trackInfo.title, trackInfo.album)

            #If a match is found in genius, fetch the track and artist url from the response
            #Lyrics State specifices if the lyrics is complete
            if matchedTrack:
                song_url = matchedTrack['url']
                artist_url = matchedTrack['primary_artist']['url']
                lyrics_state = matchedTrack['lyrics_state']

            #Store the urls in the dictionary
            if artist_url:
                featuresDict['genius_artist_url'] = artist_url
            #Use the song url to scrape the lyrics page from Genius
            if song_url:
                featuresDict['genius_track_url'] = song_url
                featuresDict['lyrics_state'] = lyrics_state
                #Retrieve the lyrics, track title, artist and album name as found in Genius
                geniusInfo = trackInfo.scrape_lyrics_artist_title(song_url)

                #Store the results in a dictionary
                #If lyrics is found, create a value as "lyrics:trackid and store it in trackDict
                #Store the text of the lyrics in a separate dictionary which is finally stored in a json file

                if geniusInfo:
                    track_lyrics = geniusInfo[0]
                    trackLyrics['lyrics:'+trackid] = track_lyrics
                    trackInfo.trackDict['lyricsId'] = 'lyrics:'+trackid

                    if geniusInfo[1]:
                        featuresDict['found_genius_title'] = geniusInfo[1]
                    if geniusInfo[2]:
                        featuresDict['found_genius_artist'] = geniusInfo[2]
                    if geniusInfo[3]:
                        featuresDict['other_track_info'] = geniusInfo[3]

            #Detect the language of the lyrics
            if track_lyrics:
                songlang = trackInfo.getTrackLanguage(track_lyrics)
                featuresDict['lyrics_language'] = songlang

            #Get the country of the Artist 
            country =  trackInfo.getArtistCountry(songlang, artist_url)
            featuresDict['artist_country'] = country

            #Get the album and artist genres and store in a dictionary
            featuresDict['artist_genres'] = str(artists_genres['artists'][i]['genres'])
            featuresDict['album_genres'] = str([])

            #Add the metadata dictionary to the ordered dictionary
            featuresDict.update(trackInfo.trackDict)

            #Store the audio analysis url in the dictionary
            featuresDict['analysis_url'] = 'https://api.spotify.com/v1/audio-analysis/' + trackid

            #Find audio features of the track and merge with the trackDict
            features = audio_features[i]
            if features:
                featuresDict.update(features)

            tracks.append(featuresDict)
            #lyrics.append(trackLyrics)

            #Calculate the request frequency per second
            req = trackInfo.req
            elapsed_time = time() - start_time
            print('label:' + str(i))
            print('Requests:{}; Frequency: {} requests/s'.format(req, req/elapsed_time))
            #clear_output(wait = True)

            #Enforce Rate limit
            #Pause the loop
            sleep(randint(2,4))

            # Break the loop if the number of requests is greater than expected
            if req > 13:
                print(i)
                print('Number of requests was greater than expected.')
                break

        k=1
        j = j+18
        if j%36 == 0:
            try:
                with open('lyrLeft.txt', 'w+') as f:    
                    json.dump(trackLyrics, f)
            except IOError:
                print('Error during file handling')      

            try:
                dfn = pd.DataFrame.from_dict(tracks)
                dfn.to_csv("songLeft.csv", index=False) 
            except:
                print("Error while writing to csv file")
                
        
    try:
        with open("lyrLeftcopy.txt", "w+") as fw:
            json.dump(trackLyrics, f3)
        
        df = pd.DataFrame.from_dict(tracks)
        df.to_csv("songLeftcopy.csv", index=False)
    except:
        print("Error while writing to files")
    

main()

# %%
song1 = pd.read_csv('songLeft.csv')
song1.shape

# %%
song1['external_ids'] = pd.Series([])

# %%
print(song1.shape)

# %%
print(song1.columns)

# %%
song1 = song1[['track_uri', 'music_title', 'music_artist', 'music_album',
       'found_title_spotify', 'found_album_spotify', 'found_artist_spotify',
       'genius_artist_url', 'genius_track_url', 'found_genius_title', 
       'found_genius_artist', 'other_track_info', 'lyrics_state', 'lyricsId',
       'lyrics_language', 'artist_country', 'artist_genres', 'album.album_type', 
       'album.artists', 'album.available_markets',
       'album.external_urls.spotify', 'album.href', 'album.id', 'album.images',
       'album.name', 'album.release_date', 'album.release_date_precision',
       'album.total_tracks', 'album.type', 'album.uri', 'artists',
       'available_markets', 'disc_number', 'duration_ms', 'explicit',
       'external_ids.isrc', 'external_urls.spotify', 'href', 'id', 'is_local',
       'name', 'popularity', 'preview_url', 'track_number', 'type',
       'uri', 'analysis_url', 'liveness', 'key', 'acousticness', 'loudness',
       'tempo', 'mode', 'time_signature', 'valence', 'speechiness',
       'track_href', 'instrumentalness', 'energy', 'danceability',
       'external_ids']]

# %%
song = pd.read_csv("songFinal.csv")

# %%
songFinal = pd.concat([song, song1])
print(songFinal.shape)

# %%
songFinal.drop_duplicates('uri', inplace=True)
songFinal.reset_index(inplace=True)
songFinal.shape
songFinal.to_csv("tracks_data.csv", index=False)

# %%
songResults = pd.read_csv('results_id_queries.csv')
songResults.shape
# Out:
# (63648, 50)

# %%
w = songFinal[:]
w.drop_duplicates('uri', inplace=True)
w.reset_index(inplace=True)
l = np.unique(w['uri']).tolist()
w.shape

# %%
q = songResults[:]
q.drop_duplicates('uri', inplace=True)
q.shape
q[~q.uri.isin(l)].shape

# %%
pd.options.display.max_columns = None
display(songResults.loc[songResults.uri == 'spotify:track:0jJ7AZj9ZDPTcofANqNB6f'])
# Out:
#                                      uri             music.artist music.album  \
# 28  spotify:track:0jJ7AZj9ZDPTcofANqNB6f  Blasterjaxx, Badd Dimes       Titan
#
#              music.title found_with_artist found_with_album  \
# 28  Titan (Original Mix)               NaN            Titan
#
#         found_with_title album.album_type  \
# 28  Titan (Original Mix)           single
#
#                                         album.artists  \
# 28  [{u'name': u'Frequencerz', u'external_urls': {...
#
#                               album.available_markets  \
# 28  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
#
#                           album.external_urls.spotify  \
# 28  https://open.spotify.com/album/0a89dFlTNGX3Mrx...
#
#                                            album.href                album.id  \
# 28  https://api.spotify.com/v1/albums/0a89dFlTNGX3...  0a89dFlTNGX3Mrx56UO05x
#
#                                          album.images   album.name  \
# 28  [{u'url': u'https://i.scdn.co/image/204ba55887...  Getting Off
#
#    album.release_date album.release_date_precision  album.total_tracks  \
# 28         2015-09-28                          day                   2
#
#    album.type                             album.uri  \
# 28      album  spotify:album:0a89dFlTNGX3Mrx56UO05x
#
#                                               artists  \
# 28  [{u'name': u'Frequencerz', u'external_urls': {...
#
#                                     available_markets  disc_number  \
# 28  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
#
#     duration_ms  explicit                                               href  \
# 28       359649     False  https://api.spotify.com/v1/tracks/0jJ7AZj9ZDPT...
#
#                         id  is_local                        name  popularity  \
# 28  0jJ7AZj9ZDPTcofANqNB6f     False  Getting Off - Original Mix          27
#
#                                           preview_url  track_number   type  \
# 28  https://p.scdn.co/mp3-preview/a6a727835b5c39fb...             2  track
#
#                                    uri.1  acousticness  \
# 28  spotify:track:0jJ7AZj9ZDPTcofANqNB6f          0.13
#
#                                          analysis_url  danceability  \
# 28  https://api.spotify.com/v1/audio-analysis/0jJ7...         0.484
#
#     duration_ms.1  energy  instrumentalness  key  liveness  loudness  mode  \
# 28         359649   0.971            0.0288    7    0.0786    -4.724     1
#
#     speechiness    tempo  time_signature  \
# 28       0.0848  150.018               4
#
#                                            track_href          type.1  valence
# 28  https://api.spotify.com/v1/tracks/0jJ7AZj9ZDPT...  audio_features    0.134

# %%
with open('lyr52755.txt') as json_file:  
    data2 = json.load(json_file) 
    
with open('lyr58812.txt') as json_file:  
    data3 = json.load(json_file)
    
with open('lyr60275.txt') as json_file:  
    data4 = json.load(json_file)
    
with open('lyr60414.txt') as json_file:  
    data5 = json.load(json_file)

with open('lyr63617.txt') as json_file:  
    data6 = json.load(json_file)
    
with open('lyrLeft.txt') as json_file:  
    data7 = json.load(json_file)

# %%
data1.update(data2)
data1.update(data3)
data1.update(data4)
data1.update(data5)
data1.update(data6)
data1.update(data7)

# %%
len(data1)
# Out:
# 35538

# %%
with open('track_lyrics.txt', 'w+') as f:
    json.dump(data1, f)

# %%
song = pd.read_csv("tracks_data.csv")
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sum(song.artist_country.notnull())
# Out:
# 28115

# %%
pd.options.display.max_columns = None
display(song)
# Out:
#        index                             track_uri  \
# 0          0  spotify:track:5JiLJJbuA92jnPoQJ7WhkK
# 1          1  spotify:track:1vScEbMXJslS5xx5noo0Ch
# 2          2  spotify:track:0RMtbz2AKZXMAL4cP0tXRm
# 3          3  spotify:track:4LzfByj2wTGZRjr8szwcFD
# 4          4  spotify:track:3QquT92Ti51799zeBywMOj
# 5          5  spotify:track:2ce5n5MpJQgvnAHtmfxS1C
# 6          6  spotify:track:43k8fgVQhZYZ6Mt6LtRnQw
# 7          7  spotify:track:5v26uKaXYsWRwWF21WVB3S
# 8          8  spotify:track:7iWWmsgELL98538Gxs6Wu7
# 9          9  spotify:track:70injMLRxsQgcRX54Vkxyz
# 10        10  spotify:track:0GATmBanwPiHQBfl2mDq3o
# 11        11  spotify:track:4oevcaqqQpR85Qmp6LqCzK
# 12        12  spotify:track:0AQ4a4Evmy00wyksgYS2WM
# 13        13  spotify:track:1QEbrQlmtYVc8l6udxhwhF
# 14        14  spotify:track:1NgaWRYfMtTls3OiXNaGus
# 15        15  spotify:track:63JD6EIQPwXMPlYCuGtXUl
# 16        16  spotify:track:654YntfsU6il9PX173dpuD
# 17        17  spotify:track:5jEipVlHWNICDhtMed5syi
# 18        18  spotify:track:7tu6IpmSey65T1TLcViLuQ
# 19        19  spotify:track:26HMjtnUHasPqQVvo38Wlw
# 20        20  spotify:track:0UFtsK5aSrq5zYai4aikAu
# 21        21  spotify:track:54xvAdU6A4HZSUac2CFtUn
# 22        22  spotify:track:79iGIEA5PpbkcOeqwRKBtj
# 23        23  spotify:track:1Bu1nVp4rWu7tQFZghpN29
# 24        24  spotify:track:1Wyo20oMjhSYX9IBstBoKT
# 25        25  spotify:track:67j4DNda2VS83bQY4OUR97
# 26        26  spotify:track:7LwNbU51jSENXgwkPXagKE
# 27        27  spotify:track:0LI4BP3JHQw0I0bFwGeiQ3
# 28        28  spotify:track:0jJ7AZj9ZDPTcofANqNB6f
# 29        29  spotify:track:2qRVadW0yxjNHooky898Nm
# ...      ...                                   ...
# 51781      7  spotify:track:03v0GxtrSCyar6Kch2sSn9
# 51782      8  spotify:track:3VRhWgnsBNI695gFwwP0Fm
# 51783      9  spotify:track:326cs7GEAbPksknw5WDeVr
# 51784     10  spotify:track:44jY8OQqymUDPS1iH8wVWb
# 51785     11  spotify:track:5vH1SaovzIDbkRssChSvNp
# 51786     12  spotify:track:3QrxoFk8gsYrIvrDQ0AhVx
# 51787     13  spotify:track:6RVEFJ6QlMmFTq53l4O4Zs
# 51788     14  spotify:track:1kDs64Dm5mZTBFj5KJVU8K
# 51789     15  spotify:track:5fBNuvGVwiuezLjxXshv9n
# 51790     16  spotify:track:4Sa47ZT3Up9fkWddvido8k
# 51791     17  spotify:track:4JAzIKBckgpbEP1cVl7RGh
# 51792     18  spotify:track:2WXTF0qgKbczC2O8VymeLO
# 51793     19  spotify:track:4PSkfgJQh6YlhH4Mlo2SSV
# 51794     20  spotify:track:2mJ53ZwjIbcnw3jPDYvh84
# 51795     21  spotify:track:4cL5MX8JL7qTYYPNkUaPC2
# 51796     22  spotify:track:456PFqZJBwC3lMBZCaJSHC
# 51797     23  spotify:track:0uCNiEE2MbtrSHCGnZEUYF
# 51798     24  spotify:track:0fyT8S6En2XyzpJm1oTcsu
# 51799     25  spotify:track:2iLbI1m75DQnbHzWjzOhGC
# 51800     26  spotify:track:3dn01ZSeCSaitXJwzWdClH
# 51801     27  spotify:track:5397TUiG9UjmYvM4H1UIF6
# 51802     28  spotify:track:5v7EkA4ninl6TzM0vjhzT1
# 51803     29  spotify:track:3Fsjt1h1p2o86pC2lQopJc
# 51804     30  spotify:track:3B1pNvHN70d44FzgKKzXib
# 51805     31  spotify:track:1ruECa4FimuEOT8OVyZBY8
# 51806     32  spotify:track:2XNxfjWBLqChCppnQPzldT
# 51807     33  spotify:track:1Qg27064zgcyaB78AgwZ4i
# 51808     34  spotify:track:3sNYqP07JKGdqno3K15I2I
# 51809     35  spotify:track:7vORhZg2DUYSJnQezoEZ3K
# 51810     36  spotify:track:2iGRy4VZ8Er6NoKuCr4sKA
#
#                                              music_title  \
# 0                        Howl At The Moon (Original Mix)
# 1                                  Save Me (Jakko Remix)
# 2                        Don't Go Lose It (Original Mix)
# 3              Apart (Martin Volt & Quentin State Remix)
# 4                              Left Behinds (Radio Edit)
# 5                                     Kuaga (Radio Edit)
# 6                                 Go Hard (Original Mix)
# 7                                             Give It Up
# 8                                 SoundWave (Radio Edit)
# 9                                Kingwood (Original Mix)
# 10                                                 Freak
# 11                          Arno Cost & Arias - At Night
# 12                                Gangsta (Original Mix)
# 13                                  Raven (Original Mix)
# 14                                   Slap (Original Mix)
# 15                                  How To Break A Heart
# 16                                   S.A.X. (Radio Edit)
# 17                       One For Love (Carl Nunes Remix)
# 18                                   Rumors (Radio Edit)
# 19                                   Winner (Radio Edit)
# 20                    Champions (feat. Harry Brooks Jnr)
# 21       Remember to Forget (Michael Mind Project Remix)
# 22       SHWDWN (Original Mix) [quality-dance-music.com]
# 23                             The Center (Original Mix)
# 24     Liberty City (Original Mix) [quality dance music]
# 25           Amazon (Original Mix) [quality dance music]
# 26                                Skyline (Original Mix)
# 27                               No Way Out (Radio Edit)
# 28                                  Titan (Original Mix)
# 29                                           Unsere Fans
# ...                                                  ...
# 51781                                                 46
# 51782                                                 47
# 51783                                                 49
# 51784                                                 71
# 51785                                                 75
# 51786                                                 85
# 51787                                                 91
# 51788                                                 97
# 51789                                                102
# 51790                                                104
# 51791                                       Expectations
# 51792                                A Sky Full Of Stars
# 51793                                  Ed Sheeran - Dive
# 51794                                Ed Sheeran - Eraser
# 51795                           Ed Sheeran - Galway Girl
# 51796                               Ed Sheeran - Happier
# 51797        Ed Sheeran - Hearts Don't Break Around Here
# 51798            Ed Sheeran - How Would You Feel (Paean)
# 51799                               Ed Sheeran - New Man
# 51800                               Ed Sheeran - Perfect
# 51801                   Ed Sheeran - Supermarket Flowers
# 51802                              Goodbye Beautiful Day
# 51803                          Better Than I Know Myself
# 51804                                             Undone
# 51805                        Ed Sheeran - What Do I Know
# 51806                           Pirelli's Miracle Elixir
# 51807                           The Worst Pies in London
# 51808                                      Rest in Peace
# 51809                                           Epiphany
# 51810                                  God, That's Good!
#
#                                       music_artist  \
# 0                             Stadiumx,Taylr Renee
# 1                           Michael Feiner & Caisa
# 2                                             MOTi
# 3               Orjan Nilsen & Jonathan Mendelsohn
# 4                        Paris Blohm & Taylr Renee
# 5                                    Pierce Fulton
# 6                                         Quintino
# 7                                      Knife Party
# 8                           R3hab & Trevor Guthrie
# 9                                        Row Rocka
# 10     Steve Aoki, Diplo & Deorro feat. Steve Bays
# 11                                       <unknown>
# 12                    DJ KUBA & NEITAN x Paul Dave
# 13                                      Toby Green
# 14                                 FTampa & Felguk
# 15                               HIFI & John Lakke
# 16                          Laidback Luke & Tujamo
# 17                                        Tom Fall
# 18                                      Pep & Rash
# 19                                        Quintino
# 20                                       Astronaut
# 21                           Carlprit Feat. Jaicko
# 22                                         Juventa
# 23                                   Marc Benjamin
# 24                                           Siege
# 25                                     Vida, JAKKO
# 26                                Sick Individuals
# 27                       Vicetone feat. Kat Nestel
# 28                         Blasterjaxx, Badd Dimes
# 29                                       Kraftklub
# ...                                            ...
# 51781                                    <unknown>
# 51782                                    <unknown>
# 51783                                    <unknown>
# 51784                                    <unknown>
# 51785                                    <unknown>
# 51786                                    <unknown>
# 51787                                    <unknown>
# 51788                                    <unknown>
# 51789                                    <unknown>
# 51790                                    <unknown>
# 51791                                    <unknown>
# 51792                                     Coldplay
# 51793                                  <Unbekannt>
# 51794                                  <Unbekannt>
# 51795                                  <Unbekannt>
# 51796                                  <Unbekannt>
# 51797                                  <Unbekannt>
# 51798                                  <Unbekannt>
# 51799                                  <Unbekannt>
# 51800                                  <Unbekannt>
# 51801                                  <Unbekannt>
# 51802                                      AVIATIC
# 51803                                 Adam Lambert
# 51804                                          FFH
# 51805                                  <Unbekannt>
# 51806                              Edwards Sanders
# 51807                         Helena Bonham Carter
# 51808    Original Cast of Buffy The Vampire Slayer
# 51809                                  Johnny Depp
# 51810                               Edward Sanders
#
#                                              music_album  \
# 0                                       Howl At The Moon
# 1                                                Save Me
# 2                                       Don't Go Lose It
# 3                                    Apart - The Remixes
# 4                                  Left Behinds - Single
# 5                                                  Kuaga
# 6                                                Go Hard
# 7                                           Abandon Ship
# 8                                              SoundWave
# 9                                               Kingwood
# 10                     Freak (feat. Steve Bays) - Single
# 11                                                  2015
# 12                                                  2015
# 13                                                  2015
# 14                                       Carry The Beats
# 15                         How To Break A Heart - Single
# 16                                                S.A.X.
# 17              One For Love (Carl Nunes Remix) - Single
# 18                                                Rumors
# 19                                                Winner
# 20                    Champions (feat. Harry Brooks Jnr)
# 21                                    Remember to Forget
# 22                               quality-dance-music.com
# 23         Revealed Recordings presents ADE Sampler 2014
# 24                               quality-dance-music.com
# 25                               quality-dance-music.com
# 26                                               Skyline
# 27                                            No Way Out
# 28                                                 Titan
# 29                                            In Schwarz
# ...                                                  ...
# 51781                                              1-100
# 51782                                              1-100
# 51783                                              1-100
# 51784                                              1-100
# 51785                                              1-100
# 51786                                              1-100
# 51787                                              1-100
# 51788                                              1-100
# 51789                                      Eigene Tracks
# 51790                                      Eigene Tracks
# 51791                                   Musik für Städte
# 51792                          Ghost Stories - Live 2014
# 51793                                Ed Sheeran - Divide
# 51794                                Ed Sheeran - Divide
# 51795                                Ed Sheeran - Divide
# 51796                                Ed Sheeran - Divide
# 51797                                Ed Sheeran - Divide
# 51798                                Ed Sheeran - Divide
# 51799                                Ed Sheeran - Divide
# 51800                                Ed Sheeran - Divide
# 51801                                Ed Sheeran - Divide
# 51802                                            ARRIVAL
# 51803                                        Trespassing
# 51804                                   Wide Open Spaces
# 51805                                Ed Sheeran - Divide
# 51806  Sweeney Todd, The Demon Barber of Fleet Street...
# 51807  Sweeney Todd, The Demon Barber of Fleet Street...
# 51808  Once More, With Feeling: Buffy the Vampire Sla...
# 51809  Sweeney Todd, The Demon Barber of Fleet Street...
# 51810  Sweeney Todd, The Demon Barber of Fleet Street...
#
#                                      found_title_spotify  \
# 0                        Howl At The Moon - Original Mix
# 1                                  Save Me - Jakko Remix
# 2                        Don't Go Lose It - Original Mix
# 3              Apart - Martin Volt & Quentin State Remix
# 4                              Left Behinds - Radio Edit
# 5                         Kuaga (Lost Time) (Radio Edit)
# 6                      Samurai (Go Hard ) - Original Mix
# 7                                             Give It Up
# 8                Soundwave - Audiotricz Remix Radio Edit
# 9                                Kingwood - Original Mix
# 10                              Freak (feat. Steve Bays)
# 11                                    At Night - Dub Mix
# 12                           Deep Gangsta - Original Mix
# 13                    Oorah! (Strong Viking Anthem 2015)
# 14                                   Slap - Original Mix
# 15            How to Break a Heart (feat. Bright Lights)
# 16                                   S.A.X. - Radio Edit
# 17             One For Love (Mix Cut) - Carl Nunes Remix
# 18                                   Rumors - Radio Edit
# 19                                   Winner - Radio Edit
# 20                    Champions (feat. Harry Brooks Jnr)
# 21       Remember to Forget - Michael Mind Project Remix
# 22                                 SHWDWN - Original Mix
# 23                   The Center [Mix Cut] - Original Mix
# 24                           Liberty City - Original Mix
# 25                                 Amazon - Original Mix
# 26                                Skyline - Original Mix
# 27            No Way Out (feat. Kat Nestel) - Radio Edit
# 28                            Getting Off - Original Mix
# 29                                    Unsere Fans - Live
# ...                                                  ...
# 51781                                         Unknown 46
# 51782                                            Unknown
# 51783                5 Lieder, Op. 49: No. 4. Wiegenlied
# 51784                                        Unknown Way
# 51785                                             The 75
# 51786                  Salute to Adventurers, Chapter 85
# 51787                                    Area 91 (Outro)
# 51788                                       Unbekannt 97
# 51789                                      Nightmare 102
# 51790                 Salute to Adventurers, Chapter 104
# 51791                                Unknown Necessities
# 51792  A Sky Full of Stars - Live at the Royal Albert...
# 51793                                               Dive
# 51794                                             Eraser
# 51795                                        Galway Girl
# 51796                                            Happier
# 51797                     Hearts Don't Break Around Here
# 51798                         How Would You Feel (Paean)
# 51799                                            New Man
# 51800                                            Perfect
# 51801                                Supermarket Flowers
# 51802                              Goodbye Beautiful Day
# 51803                          Better Than I Know Myself
# 51804                                             Undone
# 51805                                    What Do I Know?
# 51806                           Pirelli's Miracle Elixir
# 51807                           The Worst Pies in London
# 51808                                      Rest in Peace
# 51809                                           Epiphany
# 51810                                  God, That's Good!
#
#                                      found_album_spotify  \
# 0                                       Howl At The Moon
# 1                                           Save Me (EP)
# 2                                       Don't Go Lose It
# 3                                        Apart (Remixes)
# 4                              Left Behinds (Radio Edit)
# 5                         Kuaga (Lost Time) (Radio Edit)
# 6            Spinnin Sessions Amsterdam Dance Event 2014
# 7                                           Abandon Ship
# 8                           Soundwave (Audiotricz Remix)
# 9                                               Kingwood
# 10                       Random White Dude Be Everywhere
# 11                      Nicky Romero presents Miami 2015
# 12                                Move Showcase ADE 2015
# 13                    Oorah! (Strong Viking Anthem 2015)
# 14                                                  Slap
# 15            How to Break a Heart (feat. Bright Lights)
# 16                                                S.A.X.
# 17        Electric For Life 2015 (Mixed by Gareth Emery)
# 18                                   Rumors (Radio Edit)
# 19                                   Winner (Radio Edit)
# 20                    Champions (feat. Harry Brooks Jnr)
# 21                                    Remember to Forget
# 22                       Love Progressive House - Vol. 2
# 23            The Sound Of Revealed 2014 (Mixed Version)
# 24               Nicky Romero presents Protocol ADE 2014
# 25               Nicky Romero presents Protocol ADE 2014
# 26                                               Skyline
# 27                         No Way Out (feat. Kat Nestel)
# 28                                           Getting Off
# 29                                        Randale (Live)
# ...                                                  ...
# 51781                                           Unknowns
# 51782                      Minimal Techno Tunes, Vol. 47
# 51783               Cantigas de Ninar: Musica para ninar
# 51784                                Astro Bass, Vol. 71
# 51785                                         Unknown EP
# 51786                   Salute to Adventurers (Abridged)
# 51787                                  Greatness Unknown
# 51788                                            Unknown
# 51789           Unknown Music from Dream Quest of Kadath
# 51790                   Salute to Adventurers (Abridged)
# 51791                        High Hopes Low Expectations
# 51792                            Ghost Stories Live 2014
# 51793                    MCP Performs Ed Sheeran: Divide
# 51794                    MCP Performs Ed Sheeran: Divide
# 51795                    MCP Performs Ed Sheeran: Divide
# 51796                    MCP Performs Ed Sheeran: Divide
# 51797                    MCP Performs Ed Sheeran: Divide
# 51798                    MCP Performs Ed Sheeran: Divide
# 51799                    MCP Performs Ed Sheeran: Divide
# 51800                    MCP Performs Ed Sheeran: Divide
# 51801          Lullaby Renditions of Ed Sheeran - Divide
# 51802                                            ARRIVAL
# 51803                       Trespassing (Deluxe Version)
# 51804                                   Wide Open Spaces
# 51805                    MCP Performs Ed Sheeran: Divide
# 51806  Sweeney Todd, The Demon Barber of Fleet Street...
# 51807  Sweeney Todd, The Demon Barber of Fleet Street...
# 51808  Once More, With Feeling: Buffy the Vampire Sla...
# 51809  Sweeney Todd, The Demon Barber of Fleet Street...
# 51810  Sweeney Todd, The Demon Barber of Fleet Street...
#
#                                     found_artist_spotify  \
# 0                                 Stadiumx & Taylr Renee
# 1                                 Michael Feiner & Caisa
# 2                                                   MOTi
# 3      Orjan Nilsen & Jonathan Mendelsohn & Martin Vo...
# 4                              Paris Blohm & Taylr Renee
# 5                                          Pierce Fulton
# 6                                                  R3HAB
# 7                                            Knife Party
# 8                    R3HAB & Trevor Guthrie & Audiotricz
# 9                                              Row Rocka
# 10              Deorro & Steve Aoki & Diplo & Steve Bays
# 11                                     Arno Cost & Arias
# 12                                       Alberto Segador
# 13                              by RAVEN & Strong Viking
# 14                                       FTampa & Felguk
# 15                     Hifi & John Lakke & Bright Lights
# 16                                Laidback Luke & Tujamo
# 17                   Tom Fall & Yoshi Breen & Carl Nunes
# 18                                            Pep & Rash
# 19                                              Quintino
# 20                          Astronaut & Harry Brooks JNR
# 21                            Carlprit & Jaicko Lawrence
# 22                                               Juventa
# 23                                         Marc Benjamin
# 24                                                 Siege
# 25                                          Vida & Jakko
# 26                                      Sick Individuals
# 27                                 Vicetone & Kat Nestel
# 28                                   Frequencerz & Titan
# 29                                             Kraftklub
# ...                                                  ...
# 51781                                       Ruven Medici
# 51782                                            Favio M
# 51783           Johannes Brahms & Diego & Unknown Artist
# 51784                                      mr. Angel boy
# 51785                                            Jerin B
# 51786                      John Buchan & unknown unknown
# 51787                         Biz the Don, The Real Newz
# 51788                                       Ruven Medici
# 51789                             Cyoakha Grace O'Manion
# 51790                      John Buchan & unknown unknown
# 51791                                          MattyPasq
# 51792                                           Coldplay
# 51793                             Molotov Cocktail Piano
# 51794                             Molotov Cocktail Piano
# 51795                             Molotov Cocktail Piano
# 51796                             Molotov Cocktail Piano
# 51797                             Molotov Cocktail Piano
# 51798                             Molotov Cocktail Piano
# 51799                             Molotov Cocktail Piano
# 51800                             Molotov Cocktail Piano
# 51801                                      Baby Rockstar
# 51802                                            AVIATIC
# 51803                                       Adam Lambert
# 51804                                                FFH
# 51805                             Molotov Cocktail Piano
# 51806  Edwards Sanders & Johnny Depp & Helena Bonham ...
# 51807                               Helena Bonham Carter
# 51808          Original Cast of Buffy The Vampire Slayer
# 51809  Johnny Depp & Helena Bonham Carter & Jamie Cam...
# 51810              Edward Sanders & Helena Bonham Carter
#
#                                        genius_artist_url  \
# 0      https://genius.com/artists/Stadiumx-and-taylr-...
# 1                                                    NaN
# 2                        https://genius.com/artists/Moti
# 3                                                    NaN
# 4                 https://genius.com/artists/Paris-blohm
# 5               https://genius.com/artists/Pierce-fulton
# 6                       https://genius.com/artists/R3hab
# 7                 https://genius.com/artists/Knife-party
# 8      https://genius.com/artists/R3hab-and-trevor-gu...
# 9                   https://genius.com/artists/Row-rocka
# 10                                                   NaN
# 11        https://genius.com/artists/Arno-cost-and-arias
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18               https://genius.com/artists/Pep-and-rash
# 19                                                   NaN
# 20                                                   NaN
# 21                   https://genius.com/artists/Carlprit
# 22                                                   NaN
# 23                                                   NaN
# 24                 https://genius.com/artists/Siege-band
# 25             https://genius.com/artists/Vida-and-jakko
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                  https://genius.com/artists/Kraftklub
# ...                                                  ...
# 51781                                                NaN
# 51782                                                NaN
# 51783                                                NaN
# 51784                                                NaN
# 51785                                                NaN
# 51786                                                NaN
# 51787                                                NaN
# 51788                                                NaN
# 51789                                                NaN
# 51790                                                NaN
# 51791               https://genius.com/artists/Mattypasq
# 51792                https://genius.com/artists/Coldplay
# 51793                                                NaN
# 51794                                                NaN
# 51795                                                NaN
# 51796                                                NaN
# 51797                                                NaN
# 51798                                                NaN
# 51799                                                NaN
# 51800                                                NaN
# 51801                                                NaN
# 51802                 https://genius.com/artists/Aviatic
# 51803            https://genius.com/artists/Adam-lambert
# 51804                     https://genius.com/artists/Ffh
# 51805                                                NaN
# 51806                                                NaN
# 51807    https://genius.com/artists/Helena-bonham-carter
# 51808                                                NaN
# 51809             https://genius.com/artists/Johnny-depp
# 51810          https://genius.com/artists/Edward-sanders
#
#                                         genius_track_url  \
# 0      https://genius.com/Stadiumx-and-taylr-renee-ho...
# 1                                                    NaN
# 2         https://genius.com/Moti-dont-go-lose-it-lyrics
# 3                                                    NaN
# 4      https://genius.com/Paris-blohm-left-behinds-ly...
# 5      https://genius.com/Pierce-fulton-kuaga-lost-ti...
# 6        https://genius.com/R3hab-samurai-go-hard-lyrics
# 7       https://genius.com/Knife-party-give-it-up-lyrics
# 8      https://genius.com/R3hab-and-trevor-guthrie-so...
# 9           https://genius.com/Row-rocka-kingwood-lyrics
# 10                                                   NaN
# 11     https://genius.com/Arno-cost-and-arias-at-nigh...
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18     https://genius.com/Pep-and-rash-rumors-radio-e...
# 19                                                   NaN
# 20                                                   NaN
# 21     https://genius.com/Carlprit-remember-to-forget...
# 22                                                   NaN
# 23                                                   NaN
# 24     https://genius.com/Siege-band-liberty-city-lyrics
# 25       https://genius.com/Vida-and-jakko-amazon-lyrics
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29       https://genius.com/Kraftklub-unsere-fans-lyrics
# ...                                                  ...
# 51781                                                NaN
# 51782                                                NaN
# 51783                                                NaN
# 51784                                                NaN
# 51785                                                NaN
# 51786                                                NaN
# 51787                                                NaN
# 51788                                                NaN
# 51789                                                NaN
# 51790                                                NaN
# 51791  https://genius.com/Mattypasq-unknown-necessiti...
# 51792  https://genius.com/Coldplay-a-sky-full-of-star...
# 51793                                                NaN
# 51794                                                NaN
# 51795                                                NaN
# 51796                                                NaN
# 51797                                                NaN
# 51798                                                NaN
# 51799                                                NaN
# 51800                                                NaN
# 51801                                                NaN
# 51802  https://genius.com/Aviatic-goodbye-beautiful-d...
# 51803  https://genius.com/Adam-lambert-better-than-i-...
# 51804               https://genius.com/Ffh-undone-lyrics
# 51805                                                NaN
# 51806                                                NaN
# 51807  https://genius.com/Helena-bonham-carter-worst-...
# 51808                                                NaN
# 51809     https://genius.com/Johnny-depp-epiphany-lyrics
# 51810  https://genius.com/Edward-sanders-god-thats-go...
#
#               found_genius_title     found_genius_artist  \
# 0               Howl At The Moon  StadiumX & Taylr Renee
# 1                            NaN                     NaN
# 2               Don’t Go Lose It                    MOTi
# 3                            NaN                     NaN
# 4                   Left Behinds             Paris Blohm
# 5              Kuaga (Lost Time)           Pierce Fulton
# 6              Samurai (go hard)                   R3HAB
# 7                     Give It Up             Knife Party
# 8                      Soundwave  R3hab & Trevor Guthrie
# 9                       Kingwood               Row Rocka
# 10                           NaN                     NaN
# 11            At Night (Dub Mix)       Arno Cost & Arias
# 12                           NaN                     NaN
# 13                           NaN                     NaN
# 14                           NaN                     NaN
# 15                           NaN                     NaN
# 16                           NaN                     NaN
# 17                           NaN                     NaN
# 18           Rumors (Radio Edit)              Pep & Rash
# 19                           NaN                     NaN
# 20                           NaN                     NaN
# 21            Remember to Forget                Carlprit
# 22                           NaN                     NaN
# 23                           NaN                     NaN
# 24                  Liberty City            Siege (band)
# 25                        Amazon            Vida & JAKKO
# 26                           NaN                     NaN
# 27                           NaN                     NaN
# 28                           NaN                     NaN
# 29                   Unsere Fans               Kraftklub
# ...                          ...                     ...
# 51781                        NaN                     NaN
# 51782                        NaN                     NaN
# 51783                        NaN                     NaN
# 51784                        NaN                     NaN
# 51785                        NaN                     NaN
# 51786                        NaN                     NaN
# 51787                        NaN                     NaN
# 51788                        NaN                     NaN
# 51789                        NaN                     NaN
# 51790                        NaN                     NaN
# 51791        Unknown Necessities               MattyPasq
# 51792        A Sky Full of Stars                Coldplay
# 51793                        NaN                     NaN
# 51794                        NaN                     NaN
# 51795                        NaN                     NaN
# 51796                        NaN                     NaN
# 51797                        NaN                     NaN
# 51798                        NaN                     NaN
# 51799                        NaN                     NaN
# 51800                        NaN                     NaN
# 51801                        NaN                     NaN
# 51802      Goodbye Beautiful Day                 Aviatic
# 51803  Better Than I Know Myself            Adam Lambert
# 51804                     Undone                     FFH
# 51805                        NaN                     NaN
# 51806                        NaN                     NaN
# 51807       Worst Pies in London    Helena Bonham Carter
# 51808                        NaN                     NaN
# 51809                   Epiphany             Johnny Depp
# 51810          God, That’s Good!          Edward Sanders
#
#                                         other_track_info lyrics_state  \
# 0      {'Produced by': '\nStadiumX\n', 'Album': 'Nick...     complete
# 1                                                    NaN          NaN
# 2                            {'Produced by': '\nMOTi\n'}     complete
# 3                                                    NaN          NaN
# 4      {'Produced by': '\nParis Blohm\n', 'Featuring'...     complete
# 5                   {'Produced by': '\nPierce Fulton\n'}     complete
# 6                                                    NaN     complete
# 7      {'Produced by': '\nGareth McGrillen & Rob Swir...     complete
# 8      {'Produced by': '\nThomas “Tawgs” Salter & R3H...     complete
# 9                       {'Produced by': '\nRow Rocka\n'}     complete
# 10                                                   NaN          NaN
# 11     {'Produced by': '\nArias & Arno Cost\n', 'Albu...     complete
# 12                                                   NaN          NaN
# 13                                                   NaN          NaN
# 14                                                   NaN          NaN
# 15                                                   NaN          NaN
# 16                                                   NaN          NaN
# 17                                                   NaN          NaN
# 18                                                   NaN     complete
# 19                                                   NaN          NaN
# 20                                                   NaN          NaN
# 21                           {'Featuring': '\nJaicko\n'}     complete
# 22                                                   NaN          NaN
# 23                                                   NaN          NaN
# 24     {'Produced by': '\nSiege (band)\n', 'Album': '...     complete
# 25     {'Produced by': '\nJakko & VIDA\n', 'Album': '...     complete
# 26                                                   NaN          NaN
# 27                                                   NaN          NaN
# 28                                                   NaN          NaN
# 29     {'Produced by': '\nPhilipp Hoppen\n', 'Album':...     complete
# ...                                                  ...          ...
# 51781                                                NaN          NaN
# 51782                                                NaN          NaN
# 51783                                                NaN          NaN
# 51784                                                NaN          NaN
# 51785                                                NaN          NaN
# 51786                                                NaN          NaN
# 51787                                                NaN          NaN
# 51788                                                NaN          NaN
# 51789                                                NaN          NaN
# 51790                                                NaN          NaN
# 51791  {'Album': 'High Hopes Low Expectations', 'Prod...     complete
# 51792  {'Album': 'Ghost Stories', 'Produced by': '\nA...     complete
# 51793                                                NaN          NaN
# 51794                                                NaN          NaN
# 51795                                                NaN          NaN
# 51796                                                NaN          NaN
# 51797                                                NaN          NaN
# 51798                                                NaN          NaN
# 51799                                                NaN          NaN
# 51800                                                NaN          NaN
# 51801                                                NaN          NaN
# 51802                               {'Album': 'Arrival'}     complete
# 51803  {'Album': 'Trespassing', 'Produced by': '\nAmm...     complete
# 51804                      {'Album': 'Wide Open Spaces'}     complete
# 51805                                                NaN          NaN
# 51806                                                NaN          NaN
# 51807  {'Album': 'Sweeney Todd: The Demon Barber of F...     complete
# 51808                                                NaN          NaN
# 51809  {'Album': 'Sweeney Todd: The Demon Barber of F...     complete
# 51810  {'Album': 'Sweeney Todd: The Demon Barber of F...     complete
#
#                             lyricsId lyrics_language          artist_country  \
# 0      lyrics:5JiLJJbuA92jnPoQJ7WhkK         English                     NaN
# 1                                NaN             NaN                     NaN
# 2      lyrics:0RMtbz2AKZXMAL4cP0tXRm         English                     NaN
# 3                                NaN             NaN                     NaN
# 4      lyrics:3QquT92Ti51799zeBywMOj         English                     NaN
# 5      lyrics:2ce5n5MpJQgvnAHtmfxS1C         English            Vermont, USA
# 6      lyrics:43k8fgVQhZYZ6Mt6LtRnQw         English                   Dutch
# 7      lyrics:5v26uKaXYsWRwWF21WVB3S         English      America, Australia
# 8      lyrics:7iWWmsgELL98538Gxs6Wu7         English                     NaN
# 9      lyrics:70injMLRxsQgcRX54Vkxyz         English                     NaN
# 10                               NaN             NaN                     NaN
# 11     lyrics:4oevcaqqQpR85Qmp6LqCzK         English                     NaN
# 12                               NaN             NaN                     NaN
# 13                               NaN             NaN                     NaN
# 14                               NaN             NaN                     NaN
# 15                               NaN             NaN                     NaN
# 16                               NaN             NaN                     NaN
# 17                               NaN             NaN                     NaN
# 18     lyrics:7tu6IpmSey65T1TLcViLuQ         English                     NaN
# 19                               NaN             NaN                     NaN
# 20                               NaN             NaN                     NaN
# 21     lyrics:54xvAdU6A4HZSUac2CFtUn         English                     NaN
# 22                               NaN             NaN                     NaN
# 23                               NaN             NaN                     NaN
# 24     lyrics:1Wyo20oMjhSYX9IBstBoKT         English                     NaN
# 25     lyrics:67j4DNda2VS83bQY4OUR97         English                     NaN
# 26                               NaN             NaN                     NaN
# 27                               NaN             NaN                     NaN
# 28                               NaN             NaN                     NaN
# 29     lyrics:2qRVadW0yxjNHooky898Nm          German                  German
# ...                              ...             ...                     ...
# 51781                            NaN             NaN                     NaN
# 51782                            NaN             NaN                     NaN
# 51783                            NaN             NaN                     NaN
# 51784                            NaN             NaN                     NaN
# 51785                            NaN             NaN                     NaN
# 51786                            NaN             NaN                     NaN
# 51787                            NaN             NaN                     NaN
# 51788                            NaN             NaN                     NaN
# 51789                            NaN             NaN                     NaN
# 51790                            NaN             NaN                     NaN
# 51791  lyrics:4JAzIKBckgpbEP1cVl7RGh         English  Bayville, NJ, TrapBang
# 51792  lyrics:2WXTF0qgKbczC2O8VymeLO         English                 British
# 51793                            NaN             NaN                     NaN
# 51794                            NaN             NaN                     NaN
# 51795                            NaN             NaN                     NaN
# 51796                            NaN             NaN                     NaN
# 51797                            NaN             NaN                     NaN
# 51798                            NaN             NaN                     NaN
# 51799                            NaN             NaN                     NaN
# 51800                            NaN             NaN                     NaN
# 51801                            NaN             NaN                     NaN
# 51802  lyrics:5v7EkA4ninl6TzM0vjhzT1         English                     NaN
# 51803  lyrics:3Fsjt1h1p2o86pC2lQopJc         English                     NaN
# 51804  lyrics:3B1pNvHN70d44FzgKKzXib         English                     NaN
# 51805                            NaN             NaN                     NaN
# 51806                            NaN             NaN                     NaN
# 51807  lyrics:1Qg27064zgcyaB78AgwZ4i         English                     NaN
# 51808                            NaN             NaN                     NaN
# 51809  lyrics:7vORhZg2DUYSJnQezoEZ3K         English                     NaN
# 51810  lyrics:2iGRy4VZ8Er6NoKuCr4sKA         English                     NaN
#
#                                            artist_genres album.album_type  \
# 0      ['big room', 'deep big room', 'edm', 'electro ...           single
# 1                                          ['melodipop']           single
# 2      ['big room', 'deep big room', 'edm', 'electro ...           single
# 3      ['big room', 'edm', 'progressive house', 'prog...           single
# 4      ['big room', 'deep big room', 'edm', 'electro ...           single
# 5      ['big room', 'complextro', 'edm', 'electro hou...           single
# 6      ['big room', 'dance pop', 'dutch house', 'edm'...      compilation
# 7      ['australian dance', 'big room', 'brostep', 'c...            album
# 8      ['big room', 'dance pop', 'dutch house', 'edm'...           single
# 9                          ['deep big room', 'sky room']           single
# 10     ['big room', 'dance pop', 'deep big room', 'ed...            album
# 11     ['big room', 'edm', 'electro house', 'progress...            album
# 12                                                    []      compilation
# 13                                                    []           single
# 14     ['brazilian edm', 'complextro', 'edm', 'electr...           single
# 15                                                    []           single
# 16     ['big room', 'deep big room', 'dutch house', '...           single
# 17     ['big room', 'deep uplifting trance', 'finnish...      compilation
# 18     ['big room', 'deep big room', 'deep groove hou...           single
# 19     ['big room', 'deep big room', 'dutch house', '...           single
# 20     ['catstep', 'complextro', 'edm', 'electro hous...           single
# 21                                      ['german dance']           single
# 22     ['progressive house', 'progressive uplifting t...      compilation
# 23                                     ['deep big room']            album
# 24                                       ['thrash core']            album
# ...
# 20     https://api.spotify.com/v1/audio-analysis/0UFt...    0.0863    6
# 21     https://api.spotify.com/v1/audio-analysis/54xv...    0.0555    5
# 22     https://api.spotify.com/v1/audio-analysis/79iG...    0.0834    5
# 23     https://api.spotify.com/v1/audio-analysis/1Bu1...    0.1110    5
# 24     https://api.spotify.com/v1/audio-analysis/1Wyo...    0.1410    0
# 25     https://api.spotify.com/v1/audio-analysis/67j4...    0.3210    6
# 26     https://api.spotify.com/v1/audio-analysis/7LwN...    0.8810    2
# 27     https://api.spotify.com/v1/audio-analysis/0LI4...    0.2410    0
# 28     https://api.spotify.com/v1/audio-analysis/0jJ7...    0.0786    7
# 29     https://api.spotify.com/v1/audio-analysis/2qRV...    0.9340    9
# ...                                                  ...       ...  ...
# 51781  https://api.spotify.com/v1/audio-analysis/03v0...    0.1160    1
# 51782  https://api.spotify.com/v1/audio-analysis/3VRh...    0.1190    1
# 51783  https://api.spotify.com/v1/audio-analysis/326c...    0.0868    0
# 51784  https://api.spotify.com/v1/audio-analysis/44jY...    0.0779    0
# 51785  https://api.spotify.com/v1/audio-analysis/5vH1...    0.0664   11
# 51786  https://api.spotify.com/v1/audio-analysis/3Qrx...    0.3630    1
# 51787  https://api.spotify.com/v1/audio-analysis/6RVE...    0.1120    0
# 51788  https://api.spotify.com/v1/audio-analysis/1kDs...    0.1070    8
# 51789  https://api.spotify.com/v1/audio-analysis/5fBN...    0.0854   11
# 51790  https://api.spotify.com/v1/audio-analysis/4Sa4...    0.1820    5
# 51791  https://api.spotify.com/v1/audio-analysis/4JAz...    0.1080   10
# 51792  https://api.spotify.com/v1/audio-analysis/2WXT...    0.7080    6
# 51793  https://api.spotify.com/v1/audio-analysis/4PSk...    0.1060    4
# 51794  https://api.spotify.com/v1/audio-analysis/2mJ5...    0.1600    8
# 51795  https://api.spotify.com/v1/audio-analysis/4cL5...    0.1170    9
# 51796  https://api.spotify.com/v1/audio-analysis/456P...    0.1040    0
# 51797  https://api.spotify.com/v1/audio-analysis/0uCN...    0.1180    7
# 51798  https://api.spotify.com/v1/audio-analysis/0fyT...    0.1100    9
# 51799  https://api.spotify.com/v1/audio-analysis/2iLb...    0.1070    4
# 51800  https://api.spotify.com/v1/audio-analysis/3dn0...    0.1220    8
# 51801  https://api.spotify.com/v1/audio-analysis/5397...    0.1150    6
# 51802  https://api.spotify.com/v1/audio-analysis/5v7E...    0.2920    7
# 51803  https://api.spotify.com/v1/audio-analysis/3Fsj...    0.1800   10
# 51804  https://api.spotify.com/v1/audio-analysis/3B1p...    0.1100    6
# 51805  https://api.spotify.com/v1/audio-analysis/1ruE...    0.2250    4
# 51806  https://api.spotify.com/v1/audio-analysis/2XNx...    0.1490    5
# 51807  https://api.spotify.com/v1/audio-analysis/1Qg2...    0.0592    0
# 51808  https://api.spotify.com/v1/audio-analysis/3sNY...    0.1340   11
# 51809  https://api.spotify.com/v1/audio-analysis/7vOR...    0.3740    5
# 51810  https://api.spotify.com/v1/audio-analysis/2iGR...    0.0519   10
#
#        acousticness  loudness    tempo  mode  time_signature  valence  \
# 0          0.002840    -3.056  127.980     0               4   0.1930
# 1          0.027700    -5.879  127.985     0               4   0.5270
# 2          0.057500    -4.029  128.003     0               4   0.7170
# 3          0.063500    -5.985  128.024     1               4   0.1670
# 4          0.001850    -4.051  128.027     0               4   0.1550
# 5          0.105000    -3.994  127.953     1               4   0.3640
# 6          0.008870    -4.976  128.019     0               4   0.2350
# 7          0.000691    -2.909  174.009     0               4   0.6480
# 8          0.060000    -4.671  148.172     1               4   0.3370
# 9          0.000842    -6.051  127.998     1               4   0.1170
# 10         0.005380    -3.486  127.948     1               4   0.2630
# 11         0.101000    -5.252  127.998     1               4   0.1140
# 12         0.070600    -7.890  121.985     1               4   0.4770
# 13         0.001420    -6.521  192.114     0               3   0.1000
# 14         0.000485    -2.588  127.994     0               4   0.2650
# 15         0.000882    -4.989  128.084     0               4   0.2960
# 16         0.001970    -3.469  127.975     1               4   0.4750
# 17         0.001740    -7.075  129.341     0               4   0.4410
# 18         0.001870    -4.478  124.948     0               4   0.4120
# 19         0.006960    -3.980  128.022     0               4   0.3770
# 20         0.121000    -3.799  127.990     0               4   0.1300
# 21         0.000848    -3.705  129.955     0               4   0.8460
# 22         0.002360    -4.028  127.992     0               4   0.4400
# 23         0.000362    -2.980  127.995     1               4   0.1690
# 24         0.000441    -6.737  128.011     0               4   0.1570
# 25         0.002170    -2.943  127.982     0               4   0.2780
# 26         0.000422    -3.591  128.006     1               4   0.4100
# 27         0.083200    -4.287  126.021     0               4   0.4250
# 28         0.130000    -4.724  150.018     1               4   0.1340
# 29         0.008430    -4.867  158.914     1               4   0.2280
# ...             ...       ...      ...   ...             ...      ...
# 51781      0.007770   -15.086  123.993     1               4   0.1980
# 51782      0.017900   -14.535  124.008     1               4   0.3200
# 51783      0.923000   -13.738  158.024     1               3   0.4760
# 51784      0.222000   -10.333   96.481     1               3   0.0329
# 51785      0.136000   -11.538  138.325     0               4   0.4540
# 51786      0.726000   -25.347   80.282     1               5   0.4790
# 51787      0.113000   -13.071   97.512     1               4   0.0370
# 51788      0.010900   -11.530  125.012     0               4   0.4350
# 51789      0.840000   -24.388   80.870     0               3   0.0885
# 51790      0.619000   -25.984   85.848     0               4   0.2950
# 51791      0.691000    -7.336   86.091     0               4   0.4940
# 51792      0.004160    -7.846  125.013     1               4   0.1860
# 51793      0.940000   -16.857  135.023     1               3   0.2570
# 51794      0.989000   -14.040  172.120     0               4   0.7270
# 51795      0.931000   -17.155  100.024     1               4   0.5230
# 51796      0.970000   -19.912  180.108     1               4   0.0379
# 51797      0.950000   -19.393  104.969     1               4   0.1670
# 51798      0.893000   -18.152  140.178     1               4   0.1030
# 51799      0.978000   -19.715   94.015     0               4   0.8210
# 51800      0.972000   -19.930  190.007     1               3   0.1800
# 51801      0.991000   -15.357  119.985     1               4   0.1240
# 51802      0.071800    -5.249  149.016     0               4   0.4610
# 51803      0.032200    -4.743  109.452     1               5   0.3080
# 51804      0.002960    -5.645  205.714     1               4   0.3600
# 51805      0.958000   -14.179  114.992     1               4   0.6110
# 51806      0.822000   -10.633  134.174     1               4   0.6300
# 51807      0.945000   -11.045   94.101     1               3   0.6380
# 51808      0.425000   -11.876  105.062     0               4   0.4330
# 51809      0.816000    -9.436  102.124     0               4   0.4760
# 51810      0.896000   -10.298   65.842     1               4   0.5340
#
#        speechiness                                         track_href  \
# 0           0.0470  https://api.spotify.com/v1/tracks/5JiLJJbuA92j...
# 1           0.0702  https://api.spotify.com/v1/tracks/1vScEbMXJslS...
# 2           0.0463  https://api.spotify.com/v1/tracks/0RMtbz2AKZXM...
# 3           0.0388  https://api.spotify.com/v1/tracks/4LzfByj2wTGZ...
# 4           0.1520  https://api.spotify.com/v1/tracks/3QquT92Ti517...
# 5           0.1250  https://api.spotify.com/v1/tracks/2ce5n5MpJQgv...
# 6           0.0382  https://api.spotify.com/v1/tracks/43k8fgVQhZYZ...
# 7           0.0641  https://api.spotify.com/v1/tracks/5v26uKaXYsWR...
# 8           0.0418  https://api.spotify.com/v1/tracks/7iWWmsgELL98...
# 9           0.1680  https://api.spotify.com/v1/tracks/70injMLRxsQg...
# 10          0.0898  https://api.spotify.com/v1/tracks/0GATmBanwPiH...
# 11          0.0636  https://api.spotify.com/v1/tracks/4oevcaqqQpR8...
# 12          0.1560  https://api.spotify.com/v1/tracks/0AQ4a4Evmy00...
# 13          0.0637  https://api.spotify.com/v1/tracks/1QEbrQlmtYVc...
# 14          0.0540  https://api.spotify.com/v1/tracks/1NgaWRYfMtTl...
# 15          0.0534  https://api.spotify.com/v1/tracks/63JD6EIQPwXM...
# 16          0.0780  https://api.spotify.com/v1/tracks/654YntfsU6il...
# 17          0.0704  https://api.spotify.com/v1/tracks/5jEipVlHWNIC...
# 18          0.0465  https://api.spotify.com/v1/tracks/7tu6IpmSey65...
# 19          0.0548  https://api.spotify.com/v1/tracks/26HMjtnUHasP...
# 20          0.0656  https://api.spotify.com/v1/tracks/0UFtsK5aSrq5...
# 21          0.1160  https://api.spotify.com/v1/tracks/54xvAdU6A4HZ...
# 22          0.3560  https://api.spotify.com/v1/tracks/79iGIEA5Ppbk...
# 23          0.0556  https://api.spotify.com/v1/tracks/1Bu1nVp4rWu7...
# 24          0.0776  https://api.spotify.com/v1/tracks/1Wyo20oMjhSY...
# 25          0.0728  https://api.spotify.com/v1/tracks/67j4DNda2VS8...
# 26          0.0643  https://api.spotify.com/v1/tracks/7LwNbU51jSEN...
# 27          0.0527  https://api.spotify.com/v1/tracks/0LI4BP3JHQw0...
# 28          0.0848  https://api.spotify.com/v1/tracks/0jJ7AZj9ZDPT...
# 29          0.2230  https://api.spotify.com/v1/tracks/2qRVadW0yxjN...
# ...            ...                                                ...
# 51781       0.0795  https://api.spotify.com/v1/tracks/03v0GxtrSCya...
# 51782       0.0812  https://api.spotify.com/v1/tracks/3VRhWgnsBNI6...
# 51783       0.0422  https://api.spotify.com/v1/tracks/326cs7GEAbPk...
# 51784       0.0753  https://api.spotify.com/v1/tracks/44jY8OQqymUD...
# 51785       0.2920  https://api.spotify.com/v1/tracks/5vH1SaovzIDb...
# 51786       0.9200  https://api.spotify.com/v1/tracks/3QrxoFk8gsYr...
# 51787       0.1040  https://api.spotify.com/v1/tracks/6RVEFJ6QlMmF...
# 51788       0.0632  https://api.spotify.com/v1/tracks/1kDs64Dm5mZT...
# 51789       0.1740  https://api.spotify.com/v1/tracks/5fBNuvGVwiue...
# 51790       0.9430  https://api.spotify.com/v1/tracks/4Sa47ZT3Up9f...
# 51791       0.3930  https://api.spotify.com/v1/tracks/4JAzIKBckgpb...
# 51792       0.0311  https://api.spotify.com/v1/tracks/2WXTF0qgKbcz...
# 51793       0.0556  https://api.spotify.com/v1/tracks/4PSkfgJQh6Yl...
# 51794       0.0607  https://api.spotify.com/v1/tracks/2mJ53ZwjIbcn...
# 51795       0.0372  https://api.spotify.com/v1/tracks/4cL5MX8JL7qT...
# 51796       0.0494  https://api.spotify.com/v1/tracks/456PFqZJBwC3...
# 51797       0.0364  https://api.spotify.com/v1/tracks/0uCNiEE2Mbtr...
# 51798       0.0390  https://api.spotify.com/v1/tracks/0fyT8S6En2Xy...
# 51799       0.0464  https://api.spotify.com/v1/tracks/2iLbI1m75DQn...
# 51800       0.0374  https://api.spotify.com/v1/tracks/3dn01ZSeCSai...
# 51801       0.0537  https://api.spotify.com/v1/tracks/5397TUiG9Ujm...
# 51802       0.0329  https://api.spotify.com/v1/tracks/5v7EkA4ninl6...
# 51803       0.1380  https://api.spotify.com/v1/tracks/3Fsjt1h1p2o8...
# 51804       0.0317  https://api.spotify.com/v1/tracks/3B1pNvHN70d4...
# 51805       0.0544  https://api.spotify.com/v1/tracks/1ruECa4FimuE...
# 51806       0.0995  https://api.spotify.com/v1/tracks/2XNxfjWBLqCh...
# 51807       0.0823  https://api.spotify.com/v1/tracks/1Qg27064zgcy...
# 51808       0.0371  https://api.spotify.com/v1/tracks/3sNYqP07JKGd...
# 51809       0.0917  https://api.spotify.com/v1/tracks/7vORhZg2DUYS...
# 51810       0.0615  https://api.spotify.com/v1/tracks/2iGRy4VZ8Er6...
#
#        instrumentalness  energy  danceability external_ids
# 0              0.274000  0.9060         0.604          NaN
# 1              0.000210  0.7540         0.718          NaN
# 2              0.473000  0.9430         0.657          NaN
# 3              0.006960  0.8940         0.629          NaN
# 4              0.033100  0.9570         0.488          NaN
# 5              0.005300  0.9700         0.602          NaN
# 6              0.773000  0.8210         0.630          NaN
# 7              0.219000  0.9700         0.553          NaN
# 8              0.000000  0.6960         0.478          NaN
# 9              0.784000  0.8160         0.806          NaN
# 10             0.132000  0.9570         0.661          NaN
# 11             0.059000  0.8640         0.634          NaN
# 12             0.442000  0.6400         0.926          NaN
# 13             0.923000  0.7550         0.292          NaN
# 14             0.774000  0.9810         0.606          NaN
# 15             0.000148  0.7430         0.512          NaN
# 16             0.844000  0.9940         0.665          NaN
# 17             0.000004  0.7990         0.504          NaN
# 18             0.009070  0.8070         0.778          NaN
# 19             0.195000  0.9090         0.693          NaN
# 20             0.000000  0.7910         0.495          NaN
# 21             0.000009  0.7950         0.689          NaN
# 22             0.399000  0.9500         0.708          NaN
# 23             0.901000  0.9910         0.494          NaN
# 24             0.852000  0.7820         0.677          NaN
# 25             0.001560  0.9780         0.608          NaN
# 26             0.876000  0.9950         0.658          NaN
# 27             0.000000  0.8640         0.576          NaN
# 28             0.028800  0.9710         0.484          NaN
# 29             0.000007  0.9680         0.512          NaN
# ...                 ...     ...           ...          ...
# 51781          0.807000  0.4960         0.804          NaN
# 51782          0.874000  0.3860         0.804          NaN
# 51783          0.930000  0.1940         0.578          NaN
# 51784          0.349000  0.7770         0.122          NaN
# 51785          0.000000  0.4660         0.759          NaN
# 51786          0.000001  0.2640         0.687          NaN
# 51787          0.000001  0.3830         0.766          NaN
# 51788          0.901000  0.6690         0.789          NaN
# 51789          0.963000  0.2920         0.309          NaN
# 51790          0.000001  0.3080         0.675          NaN
# 51791          0.000000  0.6670         0.636          NaN
# 51792          0.000059  0.7650         0.467          NaN
# 51793          0.931000  0.1570         0.718          NaN
# 51794          0.926000  0.2540         0.592          NaN
# 51795          0.892000  0.3620         0.609          NaN
# 51796          0.899000  0.1330         0.300          NaN
# 51797          0.916000  0.1650         0.406          NaN
# 51798          0.891000  0.1560         0.554          NaN
# 51799          0.952000  0.1490         0.730          NaN
# 51800          0.883000  0.1390         0.535          NaN
# 51801          0.933000  0.0351         0.492          NaN
# 51802          0.017900  0.9390         0.447          NaN
# 51803          0.000000  0.8120         0.484          NaN
# 51804          0.369000  0.7000         0.252          NaN
# 51805          0.878000  0.3260         0.774          NaN
# 51806          0.000000  0.3620         0.585          NaN
# 51807          0.000009  0.3250         0.544          NaN
# 51808          0.000000  0.3850         0.526          NaN
# 51809          0.000000  0.4840         0.521          NaN
# 51810          0.000004  0.3250         0.731          NaN
#
# [51811 rows x 62 columns]
